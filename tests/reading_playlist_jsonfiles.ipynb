# %%
import pandas as pd
import numpy as np
import json

# %%
# Opening JSON file
f = open('spotify_million_playlist_dataset_challenge/challenge_set.json')
  
data = json.load(f)

f.close()

# %%
items_list = data['playlists']

playlist_names = []
artist_names = []
track_names = []
track_uris = []
artist_uris = []
album_uris = []


for item in items_list:
    tracks = item['tracks']
    for track in tracks:
        playlist_name = item['name']
        playlist_names.append(playlist_name)
    
        artist_name = track['artist_name']
        artist_names.append(artist_name)
        
        track_name = track['track_name']
        track_names.append(track_name)
        
        track_uri = track['track_uri']
        track_uris.append(track_uri)
        
        artist_uri = track['artist_uri']
        artist_uris.append(artist_uri)
        
        album_uri = track['album_uri']
        album_uris.append(album_uri)

        

        print('Playlist Name:', name)
        print('Artist Name:', artist_name)
        print('Track Name:', track_name)
        print('Track URI:',track_uri)
        print('Artist URI:', artist_uri)
        print('Album URI:', album_uri)
        print()
    print("\n","\n","\n","\n","\n")
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
columns = ['Playlist Name', 'Artist name', 'Track Name', 'Track URI', 'Artist URI', 'Album URI']

# %%
Playlists = pd.DataFrame(data=list(zip(playlist_names, artist_names, track_names, track_uris, artist_uris, album_uris)), columns=columns)

# %%
Playlists.head(7)
# Out:
#   Playlist Name Artist name  \
# 0         Party   AronChupa
# 1         Party   AronChupa
# 2         Party       Lorde
# 3         Party       Lorde
# 4         Party       Lorde
# 5        school      Alesso
# 6        school  The Script
#
#                                           Track Name  \
# 0                                       Little Swing
# 1                                   I'm an Albatraoz
# 2  Yellow Flicker Beat - From The Hunger Games: M...
# 3                                  White Teeth Teens
# 4                                               Team
# 5                               Heroes (we could be)
# 6                                        Superheroes
#
#                               Track URI  \
# 0  spotify:track:66U0ASk1VHZsqIkpMjKX3B
# 1  spotify:track:5MhsZlmKJG6X5kTHkdwC4B
# 2  spotify:track:0GZoB8h0kqXn7XFm4Sj06k
# 3  spotify:track:35kahykNu00FPysz3C2euR
# 4  spotify:track:3G6hD9B2ZHOsgf4WfNu7X1
# 5  spotify:track:6WQLkih8nE0JdUCEyLaGnQ
# ...

# %%
Playlists.isnull().sum()
# Out:
# Playlist Name    0
# Artist name      0
# Track Name       0
# Track URI        0
# Artist URI       0
# Album URI        0
# dtype: int64

# %%
Playlists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Playlist Name  5000 non-null   object
#  1   Artist name    5000 non-null   object
#  2   Track Name     5000 non-null   object
#  3   Track URI      5000 non-null   object
#  4   Artist URI     5000 non-null   object
#  5   Album URI      5000 non-null   object
# dtypes: object(6)
# memory usage: 234.5+ KB
