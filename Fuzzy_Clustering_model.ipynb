# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import json
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pickle

# %%
# path to playlist file
root_path = !pwd
root_path = str(root_path[0])

# %%
# filename 
filepath = f"{root_path}/playlist_data/sampledata/"
filename = 'mpd.slice.0-999.json'

#filepath = f"{root_path}/playlist_data/"
#filename = 'challenge_set.json'

# %%
# path + filename
fpath_name = f"{filepath}{filename}"
# print(fpath_name)

# %%
# Open file of playlist and obtain fields of json file 
with open(fpath_name) as data_file:    
    data = json.load(data_file)

# %%
# # Explore fields in json file
# print("File keys: ", list(data.keys()))
# print("info: ",data[list(data.keys())[0]])
# #print(f"{list(data.keys())[1]} : ",data[list(data.keys())[1]])
# print("playlists: ",list(data['playlists'][0].keys()))
# print("tracks: ", list(data['playlists'][0]['tracks'][0].keys()))

# %%
# Extract track features
num_keys_old = 0
for index, playlist in enumerate(data['playlists']):
    num_keys =  len(playlist.keys())
    if index == 0:
        num_key_old = num_keys
        continue
    if num_keys > num_key_old:
        keys = playlist.keys()
    num_key_old = num_keys

# %%
# Construct keys of playlist
keys = list(keys)
keys.remove('tracks')
print(" Playlist keys: ", keys)
# Out:
#  Playlist keys:  ['name', 'collaborative', 'pid', 'modified_at', 'num_tracks', 'num_albums', 'num_followers', 'num_edits', 'duration_ms', 'num_artists', 'description']

# %%
# Create dataframe with track and playlist info
music_df = pd.json_normalize(data['playlists'],  meta = keys, meta_prefix = 'playlist_', errors='ignore', record_path=['tracks'], record_prefix = 'track_')
music_df.head()
# Out:
#    track_pos  track_artist_name                       track_track_uri  \
# 0          0      Missy Elliott  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1          1     Britney Spears  spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 2          2            Beyoncé  spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 3          3  Justin Timberlake  spotify:track:1AWQoqb9bSvzTjaLralEkT
# 4          4             Shaggy  spotify:track:1lzr43nnXAijIGYnCT8M8H
#
#                         track_artist_uri  \
# 0  spotify:artist:2wIVse2owClT7go1WT98tk
# 1  spotify:artist:26dSoYclwsYLMAKD3tpOr4
# 2  spotify:artist:6vWDO969PvNqNYHIOW5v0m
# 3  spotify:artist:31TPClRtHm23RisEBtV3X7
# 4  spotify:artist:5EvFsr3kj42KNv97ZEnqij
#
#                              track_track_name  \
# 0  Lose Control (feat. Ciara & Fat Man Scoop)
# 1                                       Toxic
# 2                               Crazy In Love
# 3                              Rock Your Body
# 4                                It Wasn't Me
#
#                         track_album_uri  track_duration_ms  \
# 0  spotify:album:6vV5UrXcfyQD1wu4Qo2I9K             226863
# 1  spotify:album:0z7pVBGOD7HCIB7S8eLkLI             198800
# 2  spotify:album:25hVFAxTlDvXbx2X2QkUkE             235933
# 3  spotify:album:6QPkyl04rXwTGlGlcYaRoW             267266
# 4  spotify:album:6NmFmPX56pcLBOFMhIiKvF             227600
#
#                                track_album_name playlist_name  \
# 0                                  The Cookbook    Throwbacks
# 1                                   In The Zone    Throwbacks
# 2  Dangerously In Love (Alben für die Ewigkeit)    Throwbacks
# 3                                     Justified    Throwbacks
# 4                                      Hot Shot    Throwbacks
#
#   playlist_collaborative playlist_pid playlist_modified_at  \
# 0                  false            0           1493424000
# 1                  false            0           1493424000
# 2                  false            0           1493424000
# 3                  false            0           1493424000
# 4                  false            0           1493424000
#
#   playlist_num_tracks playlist_num_albums playlist_num_followers  \
# 0                  52                  47                      1
# 1                  52                  47                      1
# 2                  52                  47                      1
# 3                  52                  47                      1
# 4                  52                  47                      1
#
#   playlist_num_edits playlist_duration_ms playlist_num_artists  \
# 0                  6             11532414                   37
# 1                  6             11532414                   37
# 2                  6             11532414                   37
# 3                  6             11532414                   37
# 4                  6             11532414                   37
#
#   playlist_description
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
music_df.shape
# Out:
# (67503, 19)

# %%
# Check column values 
music_df[music_df['playlist_pid'] == 0].columns
# Out:
# Index(['track_pos', 'track_artist_name', 'track_track_uri', 'track_artist_uri',
#        'track_track_name', 'track_album_uri', 'track_duration_ms',
#        'track_album_name', 'playlist_name', 'playlist_collaborative',
#        'playlist_pid', 'playlist_modified_at', 'playlist_num_tracks',
#        'playlist_num_albums', 'playlist_num_followers', 'playlist_num_edits',
#        'playlist_duration_ms', 'playlist_num_artists', 'playlist_description'],
#       dtype='object')

# %%
subset_df = music_df

# %%
len(subset_df)
# Out:
# 67503

# %%
# Select indexes of playlists that have a description
# playlists_id_with_description = music_df[~music_df['playlist_description'].isna()]['playlist_pid'].unique()
# print(playlists_id_with_description)

# %%
# Working only with playlists that contain a "description"
# subset_df = music_df[music_df['playlist_pid'].isin(playlists_id_with_description)]
# print(subset_df['playlist_pid'].unique())

# %%
num_records = len(subset_df)
num_unique_records = len(subset_df[['track_artist_name','track_track_name']].apply(lambda x: ',.'.join(x),axis=1).unique())
print('Number of table records: ', num_records)
print('Number of unique artist, song pairs: ', num_unique_records )
print('Number of repeated songs: ', num_records - num_unique_records )
print('Number of playlists: ', len(subset_df['playlist_pid'].unique()))
print('Number of unique artists: ', len(subset_df['track_artist_name'].unique()))
# Out:
# Number of table records:  67503
# Number of unique artist, song pairs:  34250
# Number of repeated songs:  33253
# Number of playlists:  1000
# Number of unique artists:  9722

# %% [markdown]
# # I have to put my IDs manually in here

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_id = ''
client_secret = ''

spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))

# %%
# Function to select track_uri ONLY Nrecords records for now
Nrecords = 500
def get_features(df, Nrecords):
    indexes = []
    audio_features = []
    track_popularity = []
    artist_genre = []
    artist_popularity = []
    album_popularity = []
    start = 0
    for row_index, row in df.iloc[0:Nrecords].iterrows():
        #print(row_index, row['track_track_uri'])
        track_uri = row['track_track_uri']
        artist_uri = row['track_artist_uri']
        album_uri = row['track_album_uri']
        if start == 0:
            keys = spotify.audio_features(tracks=track_uri)[0].keys()
        start += 1
    
        track_popularity.append(spotify.track(track_uri)['popularity'])
        
        indexes.append(row_index) 
        audio_features.append(spotify.audio_features(tracks=track_uri)[0].values())
        
        artist_results = spotify.artist(artist_uri)
        
        artist_genre.append(artist_results['genres'])
        artist_popularity.append(artist_results['popularity'])
        #print(artist_results['genres'], artist_results['popularity'])
        album_results = spotify.album(album_uri)
        album_popularity.append(album_results['popularity'])
        
        
    features_df = pd.DataFrame(audio_features, columns=keys)
    features_df['song_popularity'] = track_popularity
    features_df['artist_genre'] = artist_genre
    features_df['artist_popularity']  = artist_popularity
    features_df['album_popularity'] = album_popularity
    features_df['index'] = indexes
    features_df.set_index('index', inplace=True)
    return features_df

spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))

# %%
audio_sp_df = get_features(subset_df , Nrecords)
audio_sp_df.index.name = None
audio_sp_df.drop(['type', 'id', 'track_href', 'analysis_url'], inplace=True, axis=1)
audio_sp_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.904   0.813    4    -7.105     0       0.1210       0.03110
# 1           0.774   0.838    5    -3.914     0       0.1140       0.02490
# 2           0.664   0.758    2    -6.583     0       0.2100       0.00238
# 3           0.892   0.714    4    -6.055     0       0.1410       0.20100
# 4           0.853   0.606    0    -4.596     1       0.0713       0.05610
# ..            ...     ...  ...       ...   ...          ...           ...
# 495         0.543   0.793    0    -5.905     1       0.0403       0.22500
# 496         0.532   0.883    0    -2.743     0       0.0352       0.09510
# 497         0.595   0.653    7    -4.935     1       0.0265       0.24600
# 498         0.579   0.801    0    -7.454     1       0.0449       0.12100
# 499         0.586   0.848   11    -6.899     0       0.2970       0.03800
#
#      instrumentalness  liveness  valence    tempo  \
# 0            0.006970    0.0471    0.810  125.461
# 1            0.025000    0.2420    0.924  143.040
# 2            0.000000    0.0598    0.701   99.259
# 3            0.000234    0.0521    0.817  100.972
# 4            0.000000    0.3130    0.654   94.759
# ..                ...       ...      ...      ...
# 495          0.000114    0.3630    0.553  140.060
# 496          0.000000    0.3040    0.700   99.995
# 497          0.000000    0.2640    0.542  128.930
# 498          0.000076    0.0821    0.972  174.755
# 499          0.000640    0.1220    0.645  137.723
#
#                                       uri  duration_ms  time_signature  \
# 0    spotify:track:0UaMYEvWZi0ZqiDOoHU3YI       226864               4
# 1    spotify:track:6I9VzXrHxO9rA9A5euc8Ak       198800               4
# 2    spotify:track:0WqIKmW4BTrj3eJFmnCKMv       235933               4
# 3    spotify:track:1AWQoqb9bSvzTjaLralEkT       267267               4
# 4    spotify:track:1lzr43nnXAijIGYnCT8M8H       227600               4
# ..                                    ...          ...             ...
# 495  spotify:track:4YZFC2igC3mzuktFHSF9mY       208453               4
# 496  spotify:track:17Vry8h1fUTYg8NL6pHhem       190240               4
# 497  spotify:track:3oW6SWwGqiZSPTiAp7ZQoH       241533               4
# 498  spotify:track:2LbOTztU3giUjjYmgtKgj3       237267               4
# 499  spotify:track:0nJzekxLI0x35YtKg0FdZ2       191520               4
#
#      song_popularity                                       artist_genre  \
# 0                 69  [dance pop, hip hop, hip pop, neo soul, pop ra...
# 1                 84                                   [dance pop, pop]
# 2                 21                                         [pop, r&b]
# 3                 79                                   [dance pop, pop]
# 4                  4                [dance pop, pop rap, reggae fusion]
# ..               ...                                                ...
# 495               38                             [modern southern rock]
# 496                0  [contemporary country, country, country road, ...
# 497               75  [contemporary country, country, country road, ...
# 498               56                                          [country]
# 499               50                          [outlaw country, redneck]
#
#      artist_popularity  album_popularity
# 0                   72                62
# 1                   80                78
# 2                   87                17
# 3                   79                77
# 4                   73                 1
# ..                 ...               ...
# 495                 55                47
# 496                 59                 0
# 497                 64                69
# 498                 72                61
# 499                 56                56
#
# [500 rows x 18 columns]

# %%
# Parameters to use for the model
audio_sp_df.keys()
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'uri', 'duration_ms', 'time_signature', 'song_popularity',
#        'artist_genre', 'artist_popularity', 'album_popularity'],
#       dtype='object')

# %%
check_df = subset_df.iloc[0:Nrecords].merge(audio_sp_df, how='left' , left_on = 'track_track_uri', right_on='uri')
check_df.drop(['track_pos', 'uri', 'mode', 'playlist_duration_ms','playlist_num_albums','playlist_num_artists',  'track_artist_uri', 'track_album_uri', 'track_duration_ms','playlist_num_followers', 'playlist_num_edits', 'playlist_collaborative', 'playlist_modified_at', 'playlist_num_tracks'], inplace = True, axis=1)
check_df
# Out:
#       track_artist_name                       track_track_uri  \
# 0         Missy Elliott  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1        Britney Spears  spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 2               Beyoncé  spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 3     Justin Timberlake  spotify:track:1AWQoqb9bSvzTjaLralEkT
# 4                Shaggy  spotify:track:1lzr43nnXAijIGYnCT8M8H
# ..                  ...                                   ...
# 517  The Cadillac Three  spotify:track:4YZFC2igC3mzuktFHSF9mY
# 518          Chris Lane  spotify:track:17Vry8h1fUTYg8NL6pHhem
# 519        Travis Tritt  spotify:track:3oW6SWwGqiZSPTiAp7ZQoH
# 520        Alan Jackson  spotify:track:2LbOTztU3giUjjYmgtKgj3
# 521  Wheeler Walker Jr.  spotify:track:0nJzekxLI0x35YtKg0FdZ2
#
#                                track_track_name  \
# 0    Lose Control (feat. Ciara & Fat Man Scoop)
# 1                                         Toxic
# 2                                 Crazy In Love
# 3                                Rock Your Body
# 4                                  It Wasn't Me
# ..                                          ...
# 517                              Drunk Like You
# 518                                         Fix
# 519                It's A Great Day To Be Alive
# 520                Chattahoochee - Extended Mix
# 521                    Eatin' Pussy/Kickin' Ass
#
#                                  track_album_name playlist_name playlist_pid  \
# 0                                    The Cookbook    Throwbacks            0
# 1                                     In The Zone    Throwbacks            0
# 2    Dangerously In Love (Alben für die Ewigkeit)    Throwbacks            0
# 3                                       Justified    Throwbacks            0
# 4                                        Hot Shot    Throwbacks            0
# ..                                            ...           ...          ...
# 517                           Bury Me In My Boots  old country             9
# 518                                 Girl Problems  old country             9
# 519                            Down The Road I Go  old country             9
# 520                               16 Biggest Hits  old country             9
# 521                                  Redneck Shit  old country             9
#
#     playlist_description  danceability  energy  key  ...  instrumentalness  \
# 0                    NaN         0.904   0.813    4  ...          0.006970
# 1                    NaN         0.774   0.838    5  ...          0.025000
# 2                    NaN         0.664   0.758    2  ...          0.000000
# 3                    NaN         0.892   0.714    4  ...          0.000234
# 4                    NaN         0.853   0.606    0  ...          0.000000
# ..                   ...           ...     ...  ...  ...               ...
# 517                  NaN         0.543   0.793    0  ...          0.000114
# 518                  NaN         0.532   0.883    0  ...          0.000000
# 519                  NaN         0.595   0.653    7  ...          0.000000
# 520                  NaN         0.579   0.801    0  ...          0.000076
# 521                  NaN         0.586   0.848   11  ...          0.000640
#
#      liveness  valence    tempo  duration_ms  time_signature  song_popularity  \
# 0      0.0471    0.810  125.461       226864               4               69
# 1      0.2420    0.924  143.040       198800               4               84
# 2      0.0598    0.701   99.259       235933               4               21
# 3      0.0521    0.817  100.972       267267               4               79
# 4      0.3130    0.654   94.759       227600               4                4
# ..        ...      ...      ...          ...             ...              ...
# 517    0.3630    0.553  140.060       208453               4               38
# 518    0.3040    0.700   99.995       190240               4                0
# 519    0.2640    0.542  128.930       241533               4               75
# 520    0.0821    0.972  174.755       237267               4               56
# 521    0.1220    0.645  137.723       191520               4               50
#
#                                           artist_genre  artist_popularity  \
# 0    [dance pop, hip hop, hip pop, neo soul, pop ra...                 72
# 1                                     [dance pop, pop]                 80
# 2                                           [pop, r&b]                 87
# 3                                     [dance pop, pop]                 79
# 4                  [dance pop, pop rap, reggae fusion]                 73
# ..                                                 ...                ...
# 517                             [modern southern rock]                 55
# 518  [contemporary country, country, country road, ...                 59
# 519  [contemporary country, country, country road, ...                 64
# 520                                          [country]                 72
# 521                          [outlaw country, redneck]                 56
#
#      album_popularity
# 0                  62
# 1                  78
# 2                  17
# 3                  77
# 4                   1
# ..                ...
# 517                47
# 518                 0
# 519                69
# 520                61
# 521                56
#
# [522 rows x 23 columns]

# %%
check_df.describe()
# Out:
#        danceability      energy         key    loudness  speechiness  \
# count    522.000000  522.000000  522.000000  522.000000   522.000000
# mean       0.596734    0.680392    4.854406   -7.070588     0.075071
# std        0.163848    0.200619    3.619879    3.434959     0.074261
# min        0.084900    0.013400    0.000000  -29.917000     0.023200
# 25%        0.490000    0.553250    1.000000   -8.801250     0.034425
# 50%        0.615500    0.716000    5.000000   -6.319000     0.047150
# 75%        0.717000    0.834000    8.000000   -4.670750     0.077200
# max        0.979000    0.986000   11.000000   -1.029000     0.505000
#
#        acousticness  instrumentalness    liveness     valence       tempo  \
# count    522.000000        522.000000  522.000000  522.000000  522.000000
# mean       0.199901          0.083551    0.183640    0.519212  122.871651
# std        0.257980          0.222522    0.140149    0.224485   28.053671
# min        0.000010          0.000000    0.026800    0.038500   48.973000
# 25%        0.011375          0.000000    0.089925    0.357000  100.977500
# 50%        0.073200          0.000043    0.129000    0.520000  120.496000
# 75%        0.310500          0.006282    0.237750    0.697500  140.307500
# max        0.989000          0.991000    0.914000    0.972000  210.857000
#
#          duration_ms  time_signature  song_popularity  artist_popularity  \
# count     522.000000      522.000000       522.000000         522.000000
# mean   234150.574713        3.955939        30.701149          61.049808
# std     64341.248057        0.277037        31.548317          19.272901
# min     65306.000000        1.000000         0.000000           0.000000
# 25%    199752.250000        4.000000         0.000000          50.000000
# 50%    225113.500000        4.000000        23.000000          65.000000
# 75%    259736.750000        4.000000        61.750000          76.000000
# max    658987.000000        5.000000        85.000000          91.000000
#
#        album_popularity
# count        522.000000
# mean          31.480843
# std           31.769513
# min            0.000000
# 25%            0.000000
# 50%           27.000000
# 75%           64.000000
# max           86.000000

# %%
# Make album popularity equal to artist popularity if album popularity is 0
check_df['album_popularity'] = np.where(check_df['album_popularity'] == 0, check_df['artist_popularity'], check_df['album_popularity'])
check_df['song_popularity'] = np.where(check_df['song_popularity'] == 0, check_df['artist_popularity'], check_df['song_popularity'])
check_df
# Out:
#       track_artist_name                       track_track_uri  \
# 0         Missy Elliott  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1        Britney Spears  spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 2               Beyoncé  spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 3     Justin Timberlake  spotify:track:1AWQoqb9bSvzTjaLralEkT
# 4                Shaggy  spotify:track:1lzr43nnXAijIGYnCT8M8H
# ..                  ...                                   ...
# 517  The Cadillac Three  spotify:track:4YZFC2igC3mzuktFHSF9mY
# 518          Chris Lane  spotify:track:17Vry8h1fUTYg8NL6pHhem
# 519        Travis Tritt  spotify:track:3oW6SWwGqiZSPTiAp7ZQoH
# 520        Alan Jackson  spotify:track:2LbOTztU3giUjjYmgtKgj3
# 521  Wheeler Walker Jr.  spotify:track:0nJzekxLI0x35YtKg0FdZ2
#
#                                track_track_name  \
# 0    Lose Control (feat. Ciara & Fat Man Scoop)
# 1                                         Toxic
# 2                                 Crazy In Love
# 3                                Rock Your Body
# 4                                  It Wasn't Me
# ..                                          ...
# 517                              Drunk Like You
# 518                                         Fix
# 519                It's A Great Day To Be Alive
# 520                Chattahoochee - Extended Mix
# 521                    Eatin' Pussy/Kickin' Ass
#
#                                  track_album_name playlist_name playlist_pid  \
# 0                                    The Cookbook    Throwbacks            0
# 1                                     In The Zone    Throwbacks            0
# 2    Dangerously In Love (Alben für die Ewigkeit)    Throwbacks            0
# 3                                       Justified    Throwbacks            0
# 4                                        Hot Shot    Throwbacks            0
# ..                                            ...           ...          ...
# 517                           Bury Me In My Boots  old country             9
# 518                                 Girl Problems  old country             9
# 519                            Down The Road I Go  old country             9
# 520                               16 Biggest Hits  old country             9
# 521                                  Redneck Shit  old country             9
#
#     playlist_description  danceability  energy  key  ...  instrumentalness  \
# 0                    NaN         0.904   0.813    4  ...          0.006970
# 1                    NaN         0.774   0.838    5  ...          0.025000
# 2                    NaN         0.664   0.758    2  ...          0.000000
# 3                    NaN         0.892   0.714    4  ...          0.000234
# 4                    NaN         0.853   0.606    0  ...          0.000000
# ..                   ...           ...     ...  ...  ...               ...
# 517                  NaN         0.543   0.793    0  ...          0.000114
# 518                  NaN         0.532   0.883    0  ...          0.000000
# 519                  NaN         0.595   0.653    7  ...          0.000000
# 520                  NaN         0.579   0.801    0  ...          0.000076
# 521                  NaN         0.586   0.848   11  ...          0.000640
#
#      liveness  valence    tempo  duration_ms  time_signature  song_popularity  \
# 0      0.0471    0.810  125.461       226864               4               69
# 1      0.2420    0.924  143.040       198800               4               84
# 2      0.0598    0.701   99.259       235933               4               21
# 3      0.0521    0.817  100.972       267267               4               79
# 4      0.3130    0.654   94.759       227600               4                4
# ..        ...      ...      ...          ...             ...              ...
# 517    0.3630    0.553  140.060       208453               4               38
# 518    0.3040    0.700   99.995       190240               4               59
# 519    0.2640    0.542  128.930       241533               4               75
# 520    0.0821    0.972  174.755       237267               4               56
# 521    0.1220    0.645  137.723       191520               4               50
#
#                                           artist_genre  artist_popularity  \
# 0    [dance pop, hip hop, hip pop, neo soul, pop ra...                 72
# 1                                     [dance pop, pop]                 80
# 2                                           [pop, r&b]                 87
# 3                                     [dance pop, pop]                 79
# 4                  [dance pop, pop rap, reggae fusion]                 73
# ..                                                 ...                ...
# 517                             [modern southern rock]                 55
# 518  [contemporary country, country, country road, ...                 59
# 519  [contemporary country, country, country road, ...                 64
# 520                                          [country]                 72
# 521                          [outlaw country, redneck]                 56
#
#      album_popularity
# 0                  62
# 1                  78
# 2                  17
# 3                  77
# 4                   1
# ..                ...
# 517                47
# 518                59
# 519                69
# 520                61
# 521                56
#
# [522 rows x 23 columns]

# %%
check_df.describe()
# Out:
#        danceability      energy         key    loudness  speechiness  \
# count    522.000000  522.000000  522.000000  522.000000   522.000000
# mean       0.596734    0.680392    4.854406   -7.070588     0.075071
# std        0.163848    0.200619    3.619879    3.434959     0.074261
# min        0.084900    0.013400    0.000000  -29.917000     0.023200
# 25%        0.490000    0.553250    1.000000   -8.801250     0.034425
# 50%        0.615500    0.716000    5.000000   -6.319000     0.047150
# 75%        0.717000    0.834000    8.000000   -4.670750     0.077200
# max        0.979000    0.986000   11.000000   -1.029000     0.505000
#
#        acousticness  instrumentalness    liveness     valence       tempo  \
# count    522.000000        522.000000  522.000000  522.000000  522.000000
# mean       0.199901          0.083551    0.183640    0.519212  122.871651
# std        0.257980          0.222522    0.140149    0.224485   28.053671
# min        0.000010          0.000000    0.026800    0.038500   48.973000
# 25%        0.011375          0.000000    0.089925    0.357000  100.977500
# 50%        0.073200          0.000043    0.129000    0.520000  120.496000
# 75%        0.310500          0.006282    0.237750    0.697500  140.307500
# max        0.989000          0.991000    0.914000    0.972000  210.857000
#
#          duration_ms  time_signature  song_popularity  artist_popularity  \
# count     522.000000      522.000000       522.000000         522.000000
# mean   234150.574713        3.955939        55.409962          61.049808
# std     64341.248057        0.277037        22.665991          19.272901
# min     65306.000000        1.000000         0.000000           0.000000
# 25%    199752.250000        4.000000        42.250000          50.000000
# 50%    225113.500000        4.000000        60.000000          65.000000
# 75%    259736.750000        4.000000        73.000000          76.000000
# max    658987.000000        5.000000        90.000000          91.000000
#
#        album_popularity
# count        522.000000
# mean          55.323755
# std           22.780699
# min            0.000000
# 25%           43.000000
# 50%           61.000000
# 75%           73.000000
# max           90.000000

# %%
check_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 522 entries, 0 to 521
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_artist_name     522 non-null    object
#  1   track_track_uri       522 non-null    object
#  2   track_track_name      522 non-null    object
#  3   track_album_name      522 non-null    object
#  4   playlist_name         522 non-null    object
#  5   playlist_pid          522 non-null    object
#  6   playlist_description  0 non-null      object
#  7   danceability          522 non-null    float64
#  8   energy                522 non-null    float64
#  9   key                   522 non-null    int64
#  10  loudness              522 non-null    float64
#  11  speechiness           522 non-null    float64
#  12  acousticness          522 non-null    float64
#  13  instrumentalness      522 non-null    float64
#  14  liveness              522 non-null    float64
#  15  valence               522 non-null    float64
#  16  tempo                 522 non-null    float64
#  17  duration_ms           522 non-null    int64
#  18  time_signature        522 non-null    int64
#  19  song_popularity       522 non-null    int64
#  20  artist_genre          522 non-null    object
#  21  artist_popularity     522 non-null    int64
#  22  album_popularity      522 non-null    int64
# dtypes: float64(9), int64(6), object(8)
# memory usage: 97.9+ KB

# %%
# NLP workflow
# Need to vectorize string fields
# Use all string fields and combine them in a column containing all the words f
# from collections import Counter

# %%
check_df['artist_genre']
# Out:
# 0      [dance pop, hip hop, hip pop, neo soul, pop ra...
# 1                                       [dance pop, pop]
# 2                                             [pop, r&b]
# 3                                       [dance pop, pop]
# 4                    [dance pop, pop rap, reggae fusion]
#                              ...
# 517                               [modern southern rock]
# 518    [contemporary country, country, country road, ...
# 519    [contemporary country, country, country road, ...
# 520                                            [country]
# 521                            [outlaw country, redneck]
# Name: artist_genre, Length: 522, dtype: object

# %%
#check_df['artist_genre'] = check_df['artist_genre'].apply(lambda x: ' '.join([i.replace('-', '_') for i in x]))
check_df['artist_genre'] = check_df['artist_genre'].apply(lambda x: ' '.join([i.replace('-', '_').replace('_', '') for i in x]))

# %%
check_df
# Out:
#       track_artist_name                       track_track_uri  \
# 0         Missy Elliott  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1        Britney Spears  spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 2               Beyoncé  spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 3     Justin Timberlake  spotify:track:1AWQoqb9bSvzTjaLralEkT
# 4                Shaggy  spotify:track:1lzr43nnXAijIGYnCT8M8H
# ..                  ...                                   ...
# 517  The Cadillac Three  spotify:track:4YZFC2igC3mzuktFHSF9mY
# 518          Chris Lane  spotify:track:17Vry8h1fUTYg8NL6pHhem
# 519        Travis Tritt  spotify:track:3oW6SWwGqiZSPTiAp7ZQoH
# 520        Alan Jackson  spotify:track:2LbOTztU3giUjjYmgtKgj3
# 521  Wheeler Walker Jr.  spotify:track:0nJzekxLI0x35YtKg0FdZ2
#
#                                track_track_name  \
# 0    Lose Control (feat. Ciara & Fat Man Scoop)
# 1                                         Toxic
# 2                                 Crazy In Love
# 3                                Rock Your Body
# 4                                  It Wasn't Me
# ..                                          ...
# 517                              Drunk Like You
# 518                                         Fix
# 519                It's A Great Day To Be Alive
# 520                Chattahoochee - Extended Mix
# 521                    Eatin' Pussy/Kickin' Ass
#
#                                  track_album_name playlist_name playlist_pid  \
# 0                                    The Cookbook    Throwbacks            0
# 1                                     In The Zone    Throwbacks            0
# 2    Dangerously In Love (Alben für die Ewigkeit)    Throwbacks            0
# 3                                       Justified    Throwbacks            0
# 4                                        Hot Shot    Throwbacks            0
# ..                                            ...           ...          ...
# 517                           Bury Me In My Boots  old country             9
# 518                                 Girl Problems  old country             9
# 519                            Down The Road I Go  old country             9
# 520                               16 Biggest Hits  old country             9
# 521                                  Redneck Shit  old country             9
#
#     playlist_description  danceability  energy  key  ...  instrumentalness  \
# 0                    NaN         0.904   0.813    4  ...          0.006970
# 1                    NaN         0.774   0.838    5  ...          0.025000
# 2                    NaN         0.664   0.758    2  ...          0.000000
# 3                    NaN         0.892   0.714    4  ...          0.000234
# 4                    NaN         0.853   0.606    0  ...          0.000000
# ..                   ...           ...     ...  ...  ...               ...
# 517                  NaN         0.543   0.793    0  ...          0.000114
# 518                  NaN         0.532   0.883    0  ...          0.000000
# 519                  NaN         0.595   0.653    7  ...          0.000000
# 520                  NaN         0.579   0.801    0  ...          0.000076
# 521                  NaN         0.586   0.848   11  ...          0.000640
#
#      liveness  valence    tempo  duration_ms  time_signature  song_popularity  \
# 0      0.0471    0.810  125.461       226864               4               69
# 1      0.2420    0.924  143.040       198800               4               84
# 2      0.0598    0.701   99.259       235933               4               21
# 3      0.0521    0.817  100.972       267267               4               79
# 4      0.3130    0.654   94.759       227600               4                4
# ..        ...      ...      ...          ...             ...              ...
# 517    0.3630    0.553  140.060       208453               4               38
# 518    0.3040    0.700   99.995       190240               4               59
# 519    0.2640    0.542  128.930       241533               4               75
# 520    0.0821    0.972  174.755       237267               4               56
# 521    0.1220    0.645  137.723       191520               4               50
#
#                                           artist_genre  artist_popularity  \
# 0    dance pop hip hop hip pop neo soul pop rap r&b...                 72
# 1                                        dance pop pop                 80
# 2                                              pop r&b                 87
# 3                                        dance pop pop                 79
# 4                      dance pop pop rap reggae fusion                 73
# ..                                                 ...                ...
# 517                               modern southern rock                 55
# 518  contemporary country country country road mode...                 59
# 519  contemporary country country country road outl...                 64
# 520                                            country                 72
# 521                             outlaw country redneck                 56
#
#      album_popularity
# 0                  62
# 1                  78
# 2                  17
# 3                  77
# 4                   1
# ..                ...
# 517                47
# 518                59
# 519                69
# 520                61
# 521                56
#
# [522 rows x 23 columns]

# %%
check_df['artist_genre'] = check_df['artist_genre'].apply(lambda x: ' '.join(list(set(x.split()))))

# %%
check_df
# Out:
#       track_artist_name                       track_track_uri  \
# 0         Missy Elliott  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1        Britney Spears  spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 2               Beyoncé  spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 3     Justin Timberlake  spotify:track:1AWQoqb9bSvzTjaLralEkT
# 4                Shaggy  spotify:track:1lzr43nnXAijIGYnCT8M8H
# ..                  ...                                   ...
# 517  The Cadillac Three  spotify:track:4YZFC2igC3mzuktFHSF9mY
# 518          Chris Lane  spotify:track:17Vry8h1fUTYg8NL6pHhem
# 519        Travis Tritt  spotify:track:3oW6SWwGqiZSPTiAp7ZQoH
# 520        Alan Jackson  spotify:track:2LbOTztU3giUjjYmgtKgj3
# 521  Wheeler Walker Jr.  spotify:track:0nJzekxLI0x35YtKg0FdZ2
#
#                                track_track_name  \
# 0    Lose Control (feat. Ciara & Fat Man Scoop)
# 1                                         Toxic
# 2                                 Crazy In Love
# 3                                Rock Your Body
# 4                                  It Wasn't Me
# ..                                          ...
# 517                              Drunk Like You
# 518                                         Fix
# 519                It's A Great Day To Be Alive
# 520                Chattahoochee - Extended Mix
# 521                    Eatin' Pussy/Kickin' Ass
#
#                                  track_album_name playlist_name playlist_pid  \
# 0                                    The Cookbook    Throwbacks            0
# 1                                     In The Zone    Throwbacks            0
# 2    Dangerously In Love (Alben für die Ewigkeit)    Throwbacks            0
# 3                                       Justified    Throwbacks            0
# 4                                        Hot Shot    Throwbacks            0
# ..                                            ...           ...          ...
# 517                           Bury Me In My Boots  old country             9
# 518                                 Girl Problems  old country             9
# 519                            Down The Road I Go  old country             9
# 520                               16 Biggest Hits  old country             9
# 521                                  Redneck Shit  old country             9
#
#     playlist_description  danceability  energy  key  ...  instrumentalness  \
# 0                    NaN         0.904   0.813    4  ...          0.006970
# 1                    NaN         0.774   0.838    5  ...          0.025000
# 2                    NaN         0.664   0.758    2  ...          0.000000
# 3                    NaN         0.892   0.714    4  ...          0.000234
# 4                    NaN         0.853   0.606    0  ...          0.000000
# ..                   ...           ...     ...  ...  ...               ...
# 517                  NaN         0.543   0.793    0  ...          0.000114
# 518                  NaN         0.532   0.883    0  ...          0.000000
# 519                  NaN         0.595   0.653    7  ...          0.000000
# 520                  NaN         0.579   0.801    0  ...          0.000076
# 521                  NaN         0.586   0.848   11  ...          0.000640
#
#      liveness  valence    tempo  duration_ms  time_signature  song_popularity  \
# 0      0.0471    0.810  125.461       226864               4               69
# 1      0.2420    0.924  143.040       198800               4               84
# 2      0.0598    0.701   99.259       235933               4               21
# 3      0.0521    0.817  100.972       267267               4               79
# 4      0.3130    0.654   94.759       227600               4                4
# ..        ...      ...      ...          ...             ...              ...
# 517    0.3630    0.553  140.060       208453               4               38
# 518    0.3040    0.700   99.995       190240               4               59
# 519    0.2640    0.542  128.930       241533               4               75
# 520    0.0821    0.972  174.755       237267               4               56
# 521    0.1220    0.645  137.723       191520               4               50
#
#                                           artist_genre  artist_popularity  \
# 0    dance urban hop hip virginia soul r&b pop cont...                 72
# 1                                            dance pop                 80
# 2                                              r&b pop                 87
# 3                                            dance pop                 79
# 4                          dance reggae pop fusion rap                 73
# ..                                                 ...                ...
# 517                               modern southern rock                 55
# 518              country road contemporary rock modern                 59
# 519                   country road contemporary outlaw                 64
# 520                                            country                 72
# 521                             country outlaw redneck                 56
#
#      album_popularity
# 0                  62
# 1                  78
# 2                  17
# 3                  77
# 4                   1
# ..                ...
# 517                47
# 518                59
# 519                69
# 520                61
# 521                56
#
# [522 rows x 23 columns]

# %%
# recheck = check.apply(lambda x: list(set(x.split())))
# print(check)
# print(recheck)
# # check_df['artist_genre'] = check_df['artist_genre'].apply(lambda x: ''.join([i.replace('', '_') for i in x]))

# %%
check_df
# Out:
#       track_artist_name                       track_track_uri  \
# 0         Missy Elliott  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1        Britney Spears  spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 2               Beyoncé  spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 3     Justin Timberlake  spotify:track:1AWQoqb9bSvzTjaLralEkT
# 4                Shaggy  spotify:track:1lzr43nnXAijIGYnCT8M8H
# ..                  ...                                   ...
# 517  The Cadillac Three  spotify:track:4YZFC2igC3mzuktFHSF9mY
# 518          Chris Lane  spotify:track:17Vry8h1fUTYg8NL6pHhem
# 519        Travis Tritt  spotify:track:3oW6SWwGqiZSPTiAp7ZQoH
# 520        Alan Jackson  spotify:track:2LbOTztU3giUjjYmgtKgj3
# 521  Wheeler Walker Jr.  spotify:track:0nJzekxLI0x35YtKg0FdZ2
#
#                                track_track_name  \
# 0    Lose Control (feat. Ciara & Fat Man Scoop)
# 1                                         Toxic
# 2                                 Crazy In Love
# 3                                Rock Your Body
# 4                                  It Wasn't Me
# ..                                          ...
# 517                              Drunk Like You
# 518                                         Fix
# 519                It's A Great Day To Be Alive
# 520                Chattahoochee - Extended Mix
# 521                    Eatin' Pussy/Kickin' Ass
#
#                                  track_album_name playlist_name playlist_pid  \
# 0                                    The Cookbook    Throwbacks            0
# 1                                     In The Zone    Throwbacks            0
# 2    Dangerously In Love (Alben für die Ewigkeit)    Throwbacks            0
# 3                                       Justified    Throwbacks            0
# 4                                        Hot Shot    Throwbacks            0
# ..                                            ...           ...          ...
# 517                           Bury Me In My Boots  old country             9
# 518                                 Girl Problems  old country             9
# 519                            Down The Road I Go  old country             9
# 520                               16 Biggest Hits  old country             9
# 521                                  Redneck Shit  old country             9
#
#     playlist_description  danceability  energy  key  ...  instrumentalness  \
# 0                    NaN         0.904   0.813    4  ...          0.006970
# 1                    NaN         0.774   0.838    5  ...          0.025000
# 2                    NaN         0.664   0.758    2  ...          0.000000
# 3                    NaN         0.892   0.714    4  ...          0.000234
# 4                    NaN         0.853   0.606    0  ...          0.000000
# ..                   ...           ...     ...  ...  ...               ...
# 517                  NaN         0.543   0.793    0  ...          0.000114
# 518                  NaN         0.532   0.883    0  ...          0.000000
# 519                  NaN         0.595   0.653    7  ...          0.000000
# 520                  NaN         0.579   0.801    0  ...          0.000076
# 521                  NaN         0.586   0.848   11  ...          0.000640
#
#      liveness  valence    tempo  duration_ms  time_signature  song_popularity  \
# 0      0.0471    0.810  125.461       226864               4               69
# 1      0.2420    0.924  143.040       198800               4               84
# 2      0.0598    0.701   99.259       235933               4               21
# 3      0.0521    0.817  100.972       267267               4               79
# 4      0.3130    0.654   94.759       227600               4                4
# ..        ...      ...      ...          ...             ...              ...
# 517    0.3630    0.553  140.060       208453               4               38
# 518    0.3040    0.700   99.995       190240               4               59
# 519    0.2640    0.542  128.930       241533               4               75
# 520    0.0821    0.972  174.755       237267               4               56
# 521    0.1220    0.645  137.723       191520               4               50
#
#                                           artist_genre  artist_popularity  \
# 0    dance urban hop hip virginia soul r&b pop cont...                 72
# 1                                            dance pop                 80
# 2                                              r&b pop                 87
# 3                                            dance pop                 79
# 4                          dance reggae pop fusion rap                 73
# ..                                                 ...                ...
# 517                               modern southern rock                 55
# 518              country road contemporary rock modern                 59
# 519                   country road contemporary outlaw                 64
# 520                                            country                 72
# 521                             country outlaw redneck                 56
#
#      album_popularity
# 0                  62
# 1                  78
# 2                  17
# 3                  77
# 4                   1
# ..                ...
# 517                47
# 518                59
# 519                69
# 520                61
# 521                56
#
# [522 rows x 23 columns]

# %%
label_columns = ['track_track_name', 'artist_genre']
check_df[label_columns]
# Out:
#                                track_track_name  \
# 0    Lose Control (feat. Ciara & Fat Man Scoop)
# 1                                         Toxic
# 2                                 Crazy In Love
# 3                                Rock Your Body
# 4                                  It Wasn't Me
# ..                                          ...
# 517                              Drunk Like You
# 518                                         Fix
# 519                It's A Great Day To Be Alive
# 520                Chattahoochee - Extended Mix
# 521                    Eatin' Pussy/Kickin' Ass
#
#                                           artist_genre
# 0    dance urban hop hip virginia soul r&b pop cont...
# 1                                            dance pop
# 2                                              r&b pop
# 3                                            dance pop
# 4                          dance reggae pop fusion rap
# ..                                                 ...
# 517                               modern southern rock
# 518              country road contemporary rock modern
# 519                   country road contemporary outlaw
# 520                                            country
# 521                             country outlaw redneck
#
# [522 rows x 2 columns]

# %%
# Combine 5 fields into one
# string_field = check_df.track_track_name.str.cat(" " + check_df.artist_genre)
string_field = check_df.artist_genre
string_field = string_field.replace({"r\&b": "rhythm blues"}, regex = True)
string_field = string_field.replace({"[^A-Za-z ]+": ""}, regex = True)
#print('last song: ',string_field.tail())
# test_song = string_field[0:int(len(string_field)*0.4)]
# print(test_song)
#fraction = 0.0
#string_field = string_field[int(len(string_field)*fraction):]
string_field
# Out:
# 0      dance urban hop hip virginia soul rhythm blues...
# 1                                              dance pop
# 2                                       rhythm blues pop
# 3                                              dance pop
# 4                            dance reggae pop fusion rap
#                              ...
# 517                                 modern southern rock
# 518                country road contemporary rock modern
# 519                     country road contemporary outlaw
# 520                                              country
# 521                               country outlaw redneck
# Name: artist_genre, Length: 522, dtype: object

# %%
check_df
# Out:
#       track_artist_name                       track_track_uri  \
# 0         Missy Elliott  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1        Britney Spears  spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 2               Beyoncé  spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 3     Justin Timberlake  spotify:track:1AWQoqb9bSvzTjaLralEkT
# 4                Shaggy  spotify:track:1lzr43nnXAijIGYnCT8M8H
# ..                  ...                                   ...
# 517  The Cadillac Three  spotify:track:4YZFC2igC3mzuktFHSF9mY
# 518          Chris Lane  spotify:track:17Vry8h1fUTYg8NL6pHhem
# 519        Travis Tritt  spotify:track:3oW6SWwGqiZSPTiAp7ZQoH
# 520        Alan Jackson  spotify:track:2LbOTztU3giUjjYmgtKgj3
# 521  Wheeler Walker Jr.  spotify:track:0nJzekxLI0x35YtKg0FdZ2
#
#                                track_track_name  \
# 0    Lose Control (feat. Ciara & Fat Man Scoop)
# 1                                         Toxic
# 2                                 Crazy In Love
# 3                                Rock Your Body
# 4                                  It Wasn't Me
# ..                                          ...
# 517                              Drunk Like You
# 518                                         Fix
# 519                It's A Great Day To Be Alive
# 520                Chattahoochee - Extended Mix
# 521                    Eatin' Pussy/Kickin' Ass
#
#                                  track_album_name playlist_name playlist_pid  \
# 0                                    The Cookbook    Throwbacks            0
# 1                                     In The Zone    Throwbacks            0
# 2    Dangerously In Love (Alben für die Ewigkeit)    Throwbacks            0
# 3                                       Justified    Throwbacks            0
# 4                                        Hot Shot    Throwbacks            0
# ..                                            ...           ...          ...
# 517                           Bury Me In My Boots  old country             9
# 518                                 Girl Problems  old country             9
# 519                            Down The Road I Go  old country             9
# 520                               16 Biggest Hits  old country             9
# 521                                  Redneck Shit  old country             9
#
#     playlist_description  danceability  energy  key  ...  instrumentalness  \
# 0                    NaN         0.904   0.813    4  ...          0.006970
# 1                    NaN         0.774   0.838    5  ...          0.025000
# 2                    NaN         0.664   0.758    2  ...          0.000000
# 3                    NaN         0.892   0.714    4  ...          0.000234
# 4                    NaN         0.853   0.606    0  ...          0.000000
# ..                   ...           ...     ...  ...  ...               ...
# 517                  NaN         0.543   0.793    0  ...          0.000114
# 518                  NaN         0.532   0.883    0  ...          0.000000
# 519                  NaN         0.595   0.653    7  ...          0.000000
# 520                  NaN         0.579   0.801    0  ...          0.000076
# 521                  NaN         0.586   0.848   11  ...          0.000640
#
#      liveness  valence    tempo  duration_ms  time_signature  song_popularity  \
# 0      0.0471    0.810  125.461       226864               4               69
# 1      0.2420    0.924  143.040       198800               4               84
# 2      0.0598    0.701   99.259       235933               4               21
# 3      0.0521    0.817  100.972       267267               4               79
# 4      0.3130    0.654   94.759       227600               4                4
# ..        ...      ...      ...          ...             ...              ...
# 517    0.3630    0.553  140.060       208453               4               38
# 518    0.3040    0.700   99.995       190240               4               59
# 519    0.2640    0.542  128.930       241533               4               75
# 520    0.0821    0.972  174.755       237267               4               56
# 521    0.1220    0.645  137.723       191520               4               50
#
#                                           artist_genre  artist_popularity  \
# 0    dance urban hop hip virginia soul r&b pop cont...                 72
# 1                                            dance pop                 80
# 2                                              r&b pop                 87
# 3                                            dance pop                 79
# 4                          dance reggae pop fusion rap                 73
# ..                                                 ...                ...
# 517                               modern southern rock                 55
# 518              country road contemporary rock modern                 59
# 519                   country road contemporary outlaw                 64
# 520                                            country                 72
# 521                             country outlaw redneck                 56
#
#      album_popularity
# 0                  62
# 1                  78
# 2                  17
# 3                  77
# 4                   1
# ..                ...
# 517                47
# 518                59
# 519                69
# 520                61
# 521                56
#
# [522 rows x 23 columns]

# %%
for i in string_field:
    print(set(i.split()))
# Out:
# {'dance', 'urban', 'hop', 'hip', 'soul', 'blues', 'pop', 'rhythm', 'contemporary', 'neo', 'rap', 'virginia'}
# {'dance', 'pop'}
# {'blues', 'pop', 'rhythm'}
# {'dance', 'pop'}
# {'dance', 'reggae', 'pop', 'fusion', 'rap'}
# {'carolina', 'dance', 'south', 'urban', 'hop', 'hip', 'blues', 'pop', 'rhythm', 'contemporary', 'atl', 'rap'}
# {'carolina', 'dance', 'south', 'urban', 'hop', 'hip', 'blues', 'pop', 'rhythm', 'contemporary', 'atl', 'rap'}
# {'carolina', 'dance', 'south', 'urban', 'hop', 'hip', 'blues', 'pop', 'rhythm', 'contemporary', 'atl', 'rap'}
# {'dance', 'pop', 'group', 'girl'}
# {'dance', 'urban', 'blues', 'pop', 'rhythm', 'contemporary', 'group', 'girl'}
# {'old', 'atlanta', 'south', 'hop', 'hip', 'dirty', 'school', 'southern', 'atl', 'rap'}
# {'latin', 'canadian', 'dance', 'pop'}
# {'dance', 'pop', 'postteen'}
# {'dance', 'pop', 'postteen'}
# {'dance', 'pop', 'postteen'}
# {'dance', 'urban', 'hip', 'blues', 'pop', 'rhythm', 'contemporary', 'rap'}
# {'dance', 'urban', 'hop', 'hip', 'southern', 'blues', 'pop', 'rhythm', 'trap', 'contemporary', 'rap'}
# {'canadian', 'pop', 'candy'}
# {'blues', 'rhythm', 'rap'}
# {'blues', 'pop', 'rhythm'}
# {'dance', 'urban', 'blues', 'pop', 'rhythm', 'contemporary', 'group', 'girl'}
# {'lilith', 'wave', 'singersongwriter', 'pop', 'rock', 'new', 'permanent'}
# {'dance', 'pop', 'rap'}
# {'neon', 'texas', 'pop', 'punk'}
# {'neon', 'pixie', 'pop', 'punk', 'band', 'boy'}
# {'blues', 'rhythm', 'rap'}
# {'boy', 'pop', 'band'}
# {'hip', 'queen', 'pop', 'trap'}
# {'melbourne', 'techno', 'bounce', 'eurodance', 'international', 'german', 'europop'}
# {'dance', 'pop'}
# {'dance', 'urban', 'blues', 'pop', 'rhythm', 'contemporary'}
# {'pop'}
# {'pop'}
# {'neon', 'pop', 'punk'}
# {'neon', 'pop', 'punk'}
# {'dance', 'pop', 'rap', 'postteen'}
# {'blues', 'rhythm', 'rap'}
# {'blues', 'rhythm', 'rap'}
# {'dance', 'pop'}
# {'dance', 'urban', 'blues', 'pop', 'rhythm', 'contemporary'}
# {'canadian', 'pop'}
# {'rave', 'neosynthpop', 'room', 'escape', 'new', 'indietronica'}
# {'dance', 'wave', 'rock', 'modern', 'alternative', 'permanent'}
# {'metal', 'pop', 'punk', 'rock', 'socal', 'modern', 'alternative'}
# {'dance', 'pop', 'group', 'girl'}
# {'canadian', 'pop'}
# {'neon', 'alternative', 'metal', 'mellow', 'pop', 'punk', 'rock', 'modern', 'postgrunge', 'neo'}
# {'canadian', 'pop'}
# {'piano', 'lilith', 'mellow', 'postteen', 'pop', 'rock', 'neo'}
# {'indie', 'rap', 'pop'}
# {'pop'}
# {'dance', 'pop', 'postteen'}
# {'pop', 'postteen'}
# {'canadian', 'pop', 'candy'}
# {'neon', 'piano', 'pop', 'punk', 'rock'}
# {'neon', 'pop', 'punk'}
# {'neon', 'pop', 'punk'}
# {'metal', 'hard', 'glam', 'soft', 'album', 'rock'}
# {'scorecore'}
# {'scorecore'}
# {'scorecore'}
# {'scorecore'}
# {'scorecore'}
# {'scorecore'}
# {'scorecore'}
# {'british', 'soundtrack'}
# {'vocal', 'broadway', 'jazz', 'show', 'tunes'}
# {'show', 'movie', 'tunes', 'broadway'}
# {'vocal', 'broadway', 'jazz', 'show', 'tunes'}
# {'show', 'tunes', 'broadway'}
# {'hard', 'album', 'rock', 'classic'}
# {'grunge', 'alternative', 'pop', 'rock', 'postgrunge'}
# {'fantasy', 'power', 'metal', 'symphonic', 'gothic', 'opera', 'finnish'}
# {'british', 'soul'}
# {'british', 'classic', 'album', 'rock', 'invasion'}
# {'british', 'classic', 'album', 'rock', 'invasion'}
# {'hard', 'classic', 'southern', 'album', 'rock'}
# {'metal', 'hard', 'mellow', 'glam', 'gold', 'classic', 'soft', 'album', 'rock'}
# {'metal', 'hard', 'mellow', 'glam', 'gold', 'classic', 'soft', 'album', 'rock'}
# {'hard', 'yacht', 'mellow', 'gold', 'classic', 'soft', 'album', 'rock'}
# {'progressive', 'hard', 'gold', 'mellow', 'classic', 'soft', 'album', 'rock', 'heartland'}
# {'glam', 'rock', 'classic'}
# {'hard', 'classic', 'southern', 'album', 'rock'}
# {'metal', 'hard', 'mellow', 'glam', 'gold', 'classic', 'soft', 'album', 'rock'}
# {'hard', 'album', 'rock', 'classic'}
# {'british', 'soundtrack'}
# {'hard', 'glam', 'rock', 'metal'}
# {'swamp', 'country', 'classic', 'southern', 'rock'}
# {'metal', 'hard', 'album', 'rock', 'german'}
# {'progressive', 'metal', 'hard', 'classic', 'album', 'rock', 'canadian'}
# {'progressive', 'metal', 'hard', 'classic', 'album', 'rock', 'canadian'}
# {'progressive', 'metal', 'hard', 'classic', 'album', 'rock', 'canadian'}
# {'progressive', 'metal', 'hard', 'classic', 'album', 'rock', 'canadian'}
# {'progressive', 'metal', 'hard', 'classic', 'album', 'rock', 'canadian'}
# {'progressive', 'metal', 'hard', 'classic', 'album', 'rock', 'canadian'}
# {'progressive', 'metal', 'hard', 'classic', 'album', 'rock', 'canadian'}
# {'korean', 'blues', 'rhythm'}
# {'krap', 'kpop', 'blues', 'rhythm', 'korean'}
# {'korean', 'pop'}
# {'korean', 'pop'}
# {'boy', 'pop', 'group', 'kpop'}
# {'kpop', 'group', 'girl'}
# {'kpop'}
# {'kpop'}
# {'kpop'}
# {'kpop'}
# {'krap', 'kpop', 'blues', 'rhythm', 'korean'}
# {'krap', 'kpop', 'blues', 'rhythm', 'korean'}
# {'kpop'}
# {'kpop'}
# {'krap', 'kpop', 'blues', 'rhythm', 'korean'}
# set()
# {'krap', 'kpop', 'blues', 'rhythm', 'korean'}
# {'krap', 'kpop', 'blues', 'rhythm', 'korean'}
# {'krap', 'kpop', 'blues', 'rhythm', 'korean'}
# {'korean', 'blues', 'rhythm', 'kpop'}
# {'kpop'}
# {'kpop'}
# {'krap', 'kpop', 'blues', 'rhythm', 'korean'}
# {'boy', 'pop', 'group', 'kpop'}
# {'pop', 'kpop', 'group', 'girl'}
# {'korean', 'pop', 'singersongwriter', 'kpop'}
# {'korean', 'pop'}
# {'korean', 'pop'}
# {'boy', 'group', 'kpop'}
# {'boy', 'group', 'kpop'}
# {'krap', 'kpop', 'blues', 'rhythm', 'korean'}
# {'kpop', 'group', 'girl'}
# {'kpop', 'group', 'girl'}
# {'kpop'}
# {'kpop'}
# {'kpop'}
# {'korean', 'ost', 'jdivision'}
# {'boy', 'group', 'kpop'}
# {'boy', 'group', 'kpop'}
# {'korean', 'blues', 'rhythm'}
# {'pop', 'kpop', 'group', 'girl'}
# {'krap', 'kpop'}
# {'krap', 'kpop'}
# {'korean', 'blues', 'rhythm', 'kpop'}
# {'korean', 'blues', 'rhythm', 'kpop'}
# {'kpop'}
# {'pop', 'kpop', 'group', 'girl'}
# {'boy', 'pop', 'group', 'kpop'}
# {'boy', 'group', 'kpop'}
# {'kpop'}
# {'kpop'}
# {'kpop'}
# {'boy', 'group', 'kpop'}
# {'korean', 'pop'}
# {'krap', 'kpop', 'blues', 'rhythm', 'korean'}
# {'boy', 'pop', 'group', 'kpop'}
# set()
# {'boy', 'group', 'kpop'}
# {'kpop'}
# {'kpop'}
# {'boy', 'pop', 'group', 'kpop'}
# {'boy', 'pop', 'group', 'kpop'}
# {'boy', 'pop', 'group', 'kpop'}
# {'boy', 'pop', 'group', 'kpop'}
# {'era', 'classical', 'romanticism', 'romantic', 'late', 'french'}
# {'era', 'classical', 'romanticism', 'romantic', 'late', 'french'}
# {'indie', 'garage', 'surf', 'pop', 'rock', 'pov'}
# {'indie', 'garage', 'surf', 'pop', 'rock', 'pov'}
# {'bedroom', 'pop'}
# {'bedroom', 'pop'}
# {'queercore'}
# {'synthpop', 'romantic', 'wave', 'sophistipop', 'pop', 'rock', 'new', 'permanent'}
# set()
# {'garage', 'pov', 'indie', 'rock'}
# {'garage', 'pov', 'indie', 'rock'}
# {'garage', 'pov', 'indie', 'rock'}
# {'indie', 'hypnagogic', 'garage', 'pop', 'rock'}
# {'indie', 'hypnagogic', 'garage', 'pop', 'rock'}
# {'indie', 'hypnagogic', 'garage', 'pop', 'rock'}
# {'indie', 'hypnagogic', 'garage', 'pop', 'rock'}
# {'uk', 'pop', 'alternative'}
# {'indie', 'rock', 'australian'}
# {'brooklyn', 'neopsychedelic', 'indie', 'nu', 'dreamo', 'surf', 'shoegaze', 'dream', 'pop', 'rock', 'gaze', 'modern'}
# set()
# {'seattle', 'bubblegrunge', 'indie', 'powerpop', 'surf', 'riot', 'punk', 'grrrl'}
# {'modern', 'pop', 'power'}
# {'piano', 'indie', 'rock', 'washington'}
# {'modern', 'pop', 'power'}
# {'alternative', 'dance', 'rave', 'neosynthpop', 'indie', 'rock', 'modern', 'new', 'dancepunk', 'indietronica'}
# {'countrygaze', 'bubblegrunge', 'indie', 'alabama', 'pop', 'rock', 'chamber'}
# {'brooklyn', 'weird', 'art', 'neosynthpop', 'indie', 'america', 'pop', 'rock', 'new', 'baroque', 'alternative'}
# {'brooklyn', 'weird', 'art', 'neosynthpop', 'indie', 'america', 'pop', 'rock', 'new', 'baroque', 'alternative'}
# {'holler', 'chamber', 'and', 'indie', 'garage', 'stomp', 'pop', 'rock', 'modern', 'baroque', 'indietronica'}
# {'indie', 'garage', 'pop', 'rock', 'noise'}
# {'holler', 'and', 'indie', 'nashville', 'shimmer', 'stomp', 'pop'}
# {'modern', 'alternative', 'pop', 'rock'}
# {'holler', 'folk', 'philly', 'chamber', 'and', 'indie', 'stomp', 'pop', 'rock', 'modern', 'pov'}
# {'holler', 'and', 'indie', 'melancholia', 'jam', 'louisville', 'roots', 'stomp', 'pop', 'rock', 'band', 'chamber'}
# {'brooklyn', 'nyc', 'indie', 'shimmer', 'pop', 'electropop', 'poptimism'}
# {'brooklyn', 'nyc', 'indie', 'shimmer', 'pop', 'electropop', 'poptimism'}
# {'afrofuturism'}
# {'boy', 'band', 'rap'}
# {'boy', 'band', 'rap'}
# set()
# {'hop', 'hip', 'underground'}
# {'hop', 'hip', 'underground'}
# {'canadian', 'aesthetic', 'hop', 'hip', 'trap', 'cloud', 'ottawa', 'dark', 'rap'}
# {'pov', 'indie', 'experimental', 'pop'}
# {'pov', 'indie', 'experimental', 'pop'}
# {'pov', 'indie', 'experimental', 'pop'}
# {'ambient', 'indie', 'paso', 'el', 'shoegaze', 'dream', 'pop'}
# {'ambient', 'indie', 'paso', 'el', 'shoegaze', 'dream', 'pop'}
# {'lofi', 'pov', 'indie', 'emo'}
# {'tulsa', 'indie'}
# {'indie', 'garage', 'rock', 'modern', 'brighton'}
# {'art', 'grave', 'wave', 'indie', 'pop', 'dream', 'area', 'rock', 'bay', 'noise', 'experimental'}
# {'shoegaze'}
# {'shoegaze'}
# {'shoegaze'}
# {'shoegaze'}
# {'shoegaze'}
# {'holler', 'and', 'indie', 'oakland', 'stomp', 'pop', 'area', 'rock', 'chamber', 'bay', 'noise'}
# {'holler', 'and', 'indie', 'oakland', 'stomp', 'pop', 'area', 'rock', 'chamber', 'bay', 'noise'}
# {'holler', 'and', 'indie', 'oakland', 'stomp', 'pop', 'area', 'rock', 'chamber', 'bay', 'noise'}
# {'holler', 'and', 'indie', 'oakland', 'stomp', 'pop', 'area', 'rock', 'chamber', 'bay', 'noise'}
# {'holler', 'and', 'indie', 'oakland', 'stomp', 'pop', 'area', 'rock', 'chamber', 'bay', 'noise'}
# {'power', 'wave', 'pop', 'rock', 'modern', 'alternative', 'permanent'}
# {'lofi', 'rap'}
# {'lofi', 'rap'}
# {'lofi', 'rap'}
# {'brooklyn', 'neosynthpop', 'metropopolis', 'indie', 'indietronica'}
# {'neopsychedelic', 'kiwi', 'pop', 'rock', 'experimental'}
# {'grunge', 'alternative', 'metal', 'pop', 'rock', 'postgrunge'}
# {'francais', 'rock', 'independant'}
# {'dance', 'pop', 'contemporary', 'urban'}
# {'dance', 'pop', 'contemporary', 'urban'}
# {'russian', 'shoegaze', 'dream', 'pop', 'modern'}
# {'alternative', 'rock'}
# {'urban', 'swing', 'blues', 'contemporary', 'rhythm', 'group', 'jack', 'new', 'girl'}
# {'nz', 'indie', 'dreamo'}
# {'bedroom', 'pop'}
# {'synthpop', 'dance', 'romantic', 'wave', 'zolo', 'rock', 'new'}
# {'synthpop', 'dance', 'romantic', 'wave', 'zolo', 'rock', 'new'}
# {'synthpop', 'dance', 'romantic', 'wave', 'zolo', 'rock', 'new'}
# {'synthpop', 'dance', 'romantic', 'wave', 'zolo', 'rock', 'new'}
# {'synthpop', 'dance', 'romantic', 'wave', 'zolo', 'rock', 'new'}
# {'countrygaze', 'lofi', 'indie', 'slowcore', 'room', 'pov', 'small', 'emo'}
# {'modern', 'dream', 'pop'}
# {'art', 'indie', 'singersongwriter', 'pop', 'rock', 'chamber', 'baroque'}
# {'chillwave', 'art', 'pop', 'metropopolis'}
# {'chillwave', 'art', 'pop', 'metropopolis'}
# {'yacht', 'rock'}
# {'hardcore', 'power', 'postpunk', 'pop', 'punk', 'rock', 'posthardcore', 'noise', 'experimental', 'alternative'}
# {'hardcore', 'power', 'postpunk', 'pop', 'punk', 'rock', 'posthardcore', 'noise', 'experimental', 'alternative'}
# {'hardcore', 'power', 'postpunk', 'pop', 'punk', 'rock', 'posthardcore', 'noise', 'experimental', 'alternative'}
# {'hardcore', 'power', 'postpunk', 'pop', 'punk', 'rock', 'posthardcore', 'noise', 'experimental', 'alternative'}
# {'hardcore', 'power', 'postpunk', 'pop', 'punk', 'rock', 'posthardcore', 'noise', 'experimental', 'alternative'}
# {'mod', 'wave', 'new', 'revival'}
# set()
# {'room', 'small'}
# {'room', 'small'}
# {'mod', 'revival'}
# set()
# {'krautrock'}
# {'bluesrock', 'psychedelic'}
# {'hop', 'hip', 'conscious', 'uk', 'alternative'}
# {'hardcore', 'hop', 'hip', 'coast', 'east'}
# {'jersey', 'hop', 'hip', 'conscious', 'coast', 'east', 'new', 'rap'}
# set()
# set()
# {'bay', 'indie', 'area'}
# {'chicago', 'garage', 'indie', 'rock'}
# {'chicago', 'garage', 'indie', 'rock'}
# {'pov', 'indie'}
# {'pov', 'indie'}
# {'indie', 'soul', 'blues', 'rhythm', 'alternative'}
# {'british', 'soul', 'neo', 'psychedelic'}
# {'vocal', 'blues', 'soul', 'jazz', 'song', 'torch'}
# {'indie', 'punk', 'orgcore', 'posthardcore', 'emo'}
# {'chicago', 'hardcore', 'punk', 'posthardcore'}
# {'chicago', 'hardcore', 'punk', 'posthardcore'}
# {'chicago', 'hardcore', 'punk', 'posthardcore'}
# {'lofi', 'indie', 'newfoundland', 'room', 'small'}
# {'mn', 'indie', 'bedroom', 'pop', 'rochester'}
# set()
# {'indie', 'rock', 'pinoy'}
# {'ambient', 'folk'}
# {'garage', 'indie', 'rock'}
# {'wave', 'no', 'postpunk', 'egg', 'punk', 'rock', 'experimental'}
# {'garage', 'neopsychedelic', 'indie', 'rock'}
# {'grunge', 'spacegrunge', 'metal', 'wave', 'rock', 'alternative', 'permanent'}
# {'beatlesque', 'wave', 'madchester', 'britpop', 'rock', 'permanent'}
# {'hard', 'album', 'rock', 'classic'}
# {'lilith', 'folk', 'singersongwriter', 'ectofolk'}
# {'dance', 'urban', 'hop', 'hip', 'blues', 'pop', 'rhythm', 'contemporary', 'group', 'atl', 'girl'}
# {'grunge', 'spacegrunge', 'metal', 'wave', 'rock', 'alternative', 'permanent'}
# {'lilith', 'dance', 'wave', 'pop', 'rock', 'new', 'europop'}
# {'lilith', 'pop', 'rock'}
# {'dance', 'urban', 'blues', 'pop', 'rhythm', 'contemporary'}
# {'lilith', 'wave', 'singersongwriter', 'ectofolk', 'pop', 'rock', 'canadian', 'permanent'}
# {'wave', 'shoegaze', 'britpop', 'rock', 'permanent'}
# {'grunge', 'alternative', 'wave', 'pop', 'rock', 'postgrunge', 'permanent'}
# {'pop', 'rock', 'postgrunge'}
# {'lilith', 'dance', 'mellow', 'pop', 'rock', 'europop', 'neo'}
# {'british', 'soul', 'sophistipop'}
# set()
# {'heartland', 'pop', 'rock', 'postgrunge'}
# {'pop', 'rap'}
# {'pop'}
# {'pop'}
# {'dance', 'pop', 'rap'}
# {'hop', 'miami', 'hip'}
# {'motown', 'classic', 'soul', 'storm', 'funk', 'quiet'}
# {'dance', 'hop', 'hip', 'miami', 'pop', 'rap'}
# {'dance', 'pop', 'rap'}
# {'dance', 'pop', 'rap'}
# {'carolina', 'dance', 'south', 'urban', 'hop', 'hip', 'blues', 'pop', 'rhythm', 'contemporary', 'atl', 'rap'}
# {'soul', 'blues', 'rhythm'}
# {'old', 'school', 'hop', 'hip'}
# {'carolina', 'dance', 'south', 'urban', 'hop', 'hip', 'blues', 'pop', 'rhythm', 'contemporary', 'atl', 'rap'}
# {'carolina', 'dance', 'south', 'urban', 'hop', 'hip', 'blues', 'pop', 'rhythm', 'contemporary', 'atl', 'rap'}
# {'dance', 'pop'}
# {'kids', 'dance', 'party'}
# {'folk', 'building', 'mellow', 'gold', 'yacht', 'singersongwriter', 'adult', 'soft', 'pop', 'rock', 'standards', 'brill', 'heartland'}
# {'kids', 'dance', 'party'}
# {'art', 'pop', 'dance'}
# {'art', 'pop', 'dance'}
# {'melbourne', 'techno', 'bounce', 'eurodance', 'international', 'german', 'europop'}
# {'house', 'electro', 'filter', 'rock'}
# {'art', 'pop', 'dance'}
# {'art', 'pop', 'dance'}
# {'dance', 'hop', 'hip', 'miami', 'pop', 'rap'}
# {'dance', 'hop', 'hip', 'miami', 'pop'}
# {'dance', 'pop', 'rap'}
# {'pop', 'contemporary', 'barbadian', 'urban'}
# {'dance', 'mellow', 'pop', 'rock', 'neo'}
# {'blues', 'rhythm', 'rap'}
# {'blues', 'rhythm', 'rap'}
# {'hop', 'hip', 'pop', 'queens', 'rap'}
# {'vocal', 'blues', 'soul', 'jazz', 'song', 'torch'}
# {'disco', 'rock', 'funk'}
# set()
# {'soul', 'blues', 'rhythm'}
# {'dance', 'pop', 'rap'}
# {'dance', 'pop', 'rap'}
# {'hop', 'hip', 'pop', 'rap'}
# {'soul', 'blues', 'rhythm'}
# {'reggae', 'roots'}
# {'dance', 'pop'}
# {'uk', 'pop'}
# {'dance', 'pop'}
# {'mellow', 'pop', 'rock', 'neo'}
# {'dance', 'mellow', 'pop', 'acoustic', 'neo'}
# {'lilith', 'pop', 'rock'}
# {'modern', 'pop', 'rock'}
# {'modern', 'pop', 'rock'}
# {'blues', 'contemporary', 'rhythm', 'urban'}
# {'british', 'alternative', 'rock'}
# {'mellow', 'dance', 'pop', 'neo'}
# {'blues', 'pop', 'rhythm'}
# {'mellow', 'jam', 'pop', 'rock', 'band', 'neo'}
# {'dance', 'pop', 'rap'}
# {'dance', 'pop', 'rap'}
# {'pop'}
# {'country', 'road', 'contemporary'}
# {'country', 'road', 'contemporary'}
# {'country', 'road', 'contemporary'}
# {'country', 'road', 'contemporary'}
# {'country', 'road', 'contemporary'}
# {'country', 'road', 'contemporary'}
# {'hard', 'mellow', 'gold', 'singersongwriter', 'classic', 'soft', 'album', 'rock', 'heartland'}
# {'dance', 'pop', 'rap'}
# {'trance', 'dance', 'dutch', 'brostep', 'house', 'slap', 'big', 'room', 'pop', 'edm'}
# {'trance', 'dance', 'dutch', 'brostep', 'house', 'slap', 'big', 'room', 'pop', 'edm'}
# {'dance', 'pop', 'rap'}
# {'dance', 'pop', 'rap'}
# {'folkpop', 'holler', 'mellow', 'and', 'stomp', 'rock', 'modern', 'neo'}
# {'dance', 'hop', 'hip', 'miami', 'pop', 'rap'}
# {'dance', 'hop', 'hip', 'miami', 'pop', 'rap'}
# {'dance', 'hop', 'hip', 'miami', 'pop', 'rap'}
# {'hop', 'hip', 'coast', 'west', 'rock', 'gangster', 'rap'}
# {'old', 'atlanta', 'hardcore', 'hop', 'hip', 'school', 'pop', 'gangster', 'rap'}
# {'sound', 'minneapolis', 'urban', 'swing', 'blues', 'rhythm', 'contemporary', 'band', 'jack', 'boy', 'new'}
# {'trance', 'dance', 'dutch', 'brostep', 'house', 'slap', 'big', 'room', 'pop', 'edm'}
# {'trance', 'dance', 'dutch', 'brostep', 'house', 'slap', 'big', 'room', 'pop', 'edm'}
# {'blues', 'rhythm', 'rap'}
# {'blues', 'rhythm', 'rap'}
# {'modern', 'pop', 'rock'}
# {'modern', 'pop', 'rock'}
# {'country', 'road', 'pop', 'contemporary', 'rock', 'modern'}
# {'blues', 'rhythm', 'rap'}
# {'uk', 'pop', 'dance', 'funky'}
# {'pop', 'postteen'}
# {'art', 'metropopolis', 'candy', 'pop', 'uk'}
# {'progressive', 'dance', 'house', 'electro', 'pop', 'edm', 'uk'}
# {'urbano', 'rap', 'reggaeton', 'latin', 'latina', 'pop', 'viral', 'latino'}
# {'pop'}
# {'seattle', 'hop', 'hip', 'pop', 'rap'}
# {'dance', 'hop', 'hip', 'miami', 'pop'}
# set()
# {'swamp', 'country', 'classic', 'southern', 'rock'}
# {'indie', 'rock', 'indietronica'}
# {'alternative', 'metal', 'reggae', 'nu', 'pop', 'rock', 'funk', 'fusion', 'rap'}
# {'holler', 'folk', 'and', 'indie', 'blues', 'stomp', 'rock', 'modern', 'new', 'americana'}
# {'grunge', 'alternative', 'rock', 'postgrunge'}
# {'stoner', 'grunge', 'scene', 'metal', 'nu', 'rock', 'modern', 'desert', 'alternative', 'palm'}
# {'irish', 'pop', 'rock'}
# {'hardcore', 'jersey', 'horror', 'punk', 'new'}
# {'hardcore', 'jersey', 'horror', 'punk', 'new'}
# {'hardcore', 'jersey', 'horror', 'punk', 'new'}
# {'shimmer', 'pop'}
# {'postgrunge'}
# {'neopsychedelic', 'psych', 'rock', 'australian', 'modern'}
# {'dance', 'pop', 'australian'}
# {'dance', 'pop', 'australian'}
# {'wave', 'indie', 'garage', 'rock', 'modern', 'sheffield', 'permanent'}
# {'indie', 'folk'}
# {'holler', 'folk', 'and', 'indie', 'singersongwriter', 'stomp', 'pop', 'chamber', 'irish'}
# {'z', 'brooklyn', 'alt', 'metropopolis', 'nyc', 'vapor', 'indie', 'pop', 'electropop', 'dark', 'poptimism'}
# {'canadian', 'blues', 'contemporary', 'rhythm'}
# {'aussietronica'}
# {'metropopolis', 'indietronica'}
# {'z', 'electropop', 'alt'}
# {'reggae', 'fusion', 'australian'}
# {'etherpop', 'electropop', 'indie'}
# {'z', 'electropop', 'alt'}
# {'poptimism', 'pov', 'indie', 'electropop'}
# {'art', 'poptimism', 'indie', 'shimmer', 'pop', 'electropop', 'indietronica'}
# {'dance', 'hop', 'hip', 'coast', 'pop', 'east', 'rap'}
# {'downtempo', 'dance', 'indie', 'australian', 'edm', 'electropop', 'indietronica'}
# set()
# {'indie', 'pop', 'etherpop', 'electropop', 'poptimism'}
# {'nyc', 'pop'}
# {'brisbane', 'indie', 'aussietronica', 'australian'}
# {'brisbane', 'indie', 'aussietronica', 'australian'}
# {'metropopolis', 'nottingham', 'indie'}
# {'hop', 'hip', 'atl', 'rap'}
# {'pop', 'la'}
# set()
# set()
# {'soul', 'indie', 'electronica'}
# {'modern', 'britpop', 'welsh', 'rock'}
# set()
# {'dance', 'pop', 'uk', 'funky'}
# {'british', 'alternative', 'rock'}
# {'holler', 'folk', 'and', 'indie', 'stomp', 'pop', 'australian', 'acoustic'}
# set()
# {'dutch', 'pop'}
# {'devotional', 'world'}
# {'pop', 'norwegian'}
# {'downtempo', 'hop', 'hip', 'nu', 'electronica', 'jazztronica', 'jazz', 'instrumental', 'indietronica', 'trip'}
# {'british', 'soul'}
# {'art', 'downtempo', 'indie', 'shimmer', 'soul', 'pop', 'indietronica'}
# {'indie', 'anthemfolk'}
# {'brisbane', 'indie', 'aussietronica', 'australian'}
# {'brisbane', 'indie', 'aussietronica', 'australian'}
# {'vapor', 'blues', 'soul', 'rhythm', 'neo'}
# set()
# {'shimmer', 'pop'}
# set()
# {'dance', 'pop'}
# {'dance', 'pop', 'uk', 'funky'}
# {'dance', 'house', 'edm', 'uk', 'indietronica'}
# {'pop', 'australian'}
# {'detroit', 'hop', 'hip', 'southern', 'blues', 'trap', 'rhythm', 'queen', 'rap'}
# {'neosynthpop', 'metropopolis', 'nyc', 'indie', 'pop', 'hopebeat', 'poptimism'}
# {'nyc', 'pop'}
# {'metropopolis', 'indietronica'}
# {'indie', 'australian'}
# {'pop', 'viral'}
# {'dancefloor', 'liquid', 'bass', 'and', 'drum', 'funk', 'dnb'}
# {'stomp', 'pop', 'rock', 'modern', 'welsh', 'alternative'}
# {'stomp', 'pop', 'rock', 'modern', 'welsh', 'alternative'}
# {'indie', 'blues', 'punk', 'rock', 'modern', 'pov', 'alternative'}
# {'metal', 'wave', 'rock', 'funk', 'alternative', 'permanent'}
# {'alternative', 'metal', 'reggae', 'nu', 'pop', 'rock', 'funk', 'fusion', 'rap'}
# {'indie', 'garage', 'rock', 'modern', 'brighton'}
# {'piano', 'holler', 'and', 'indie', 'stomp', 'rock', 'modern', 'alternative'}
# {'piano', 'holler', 'and', 'indie', 'stomp', 'rock', 'modern', 'alternative'}
# {'modern', 'rock'}
# {'mellow', 'pop', 'rock', 'modern', 'uk', 'baroque', 'alternative', 'neo'}
# {'mellow', 'pop', 'rock', 'modern', 'uk', 'baroque', 'alternative', 'neo'}
# {'beatlesque', 'british', 'classic', 'rock', 'psychedelic', 'merseybeat', 'invasion'}
# {'modern', 'rock'}
# {'metal', 'wave', 'rock', 'funk', 'alternative', 'permanent'}
# {'metal', 'wave', 'rock', 'funk', 'alternative', 'permanent'}
# {'wave', 'punk', 'rock', 'modern', 'permanent'}
# {'wave', 'punk', 'rock', 'modern', 'permanent'}
# {'holler', 'folk', 'and', 'indie', 'stomp', 'rock', 'modern'}
# {'beatlesque', 'british', 'classic', 'rock', 'psychedelic', 'merseybeat', 'invasion'}
# {'indie', 'indietronica', 'rock', 'modern', 'alternative'}
# {'indie', 'indietronica', 'rock', 'modern', 'alternative'}
# {'stomp', 'pop', 'rock', 'modern', 'welsh', 'alternative'}
# {'la', 'indie', 'rock', 'modern', 'pov', 'alternative'}
# {'beatlesque', 'british', 'classic', 'rock', 'psychedelic', 'merseybeat', 'invasion'}
# {'beatlesque', 'british', 'classic', 'rock', 'psychedelic', 'merseybeat', 'invasion'}
# {'hop', 'hip', 'rock', 'modern', 'alternative'}
# {'holler', 'chamber', 'and', 'indie', 'garage', 'stomp', 'pop', 'rock', 'modern', 'baroque', 'indietronica'}
# {'beatlesque', 'british', 'classic', 'rock', 'psychedelic', 'merseybeat', 'invasion'}
# {'art', 'beatlesque', 'symphonic', 'mellow', 'glam', 'gold', 'classic', 'soft', 'album', 'rock'}
# {'reggae', 'fusion', 'rock'}
# {'mellow', 'pop', 'rock', 'modern', 'uk', 'baroque', 'alternative', 'neo'}
# {'metal', 'wave', 'rock', 'funk', 'alternative', 'permanent'}
# {'la', 'indie', 'rock', 'modern', 'pov', 'alternative'}
# {'metal', 'wave', 'rock', 'funk', 'alternative', 'permanent'}
# {'reggae', 'fusion', 'uk'}
# {'beatlesque', 'british', 'classic', 'rock', 'psychedelic', 'merseybeat', 'invasion'}
# {'seattle', 'alternative', 'chamber', 'indie', 'pop', 'rock', 'modern', 'indietronica', 'washington'}
# {'metal', 'wave', 'rock', 'funk', 'alternative', 'permanent'}
# {'beatlesque', 'british', 'classic', 'rock', 'psychedelic', 'merseybeat', 'invasion'}
# {'folk', 'beatlesque', 'mellow', 'sunshine', 'gold', 'singersongwriter', 'classic', 'bubblegum', 'soft', 'pop', 'album', 'rock', 'heartland', 'rockandroll'}
# {'beatlesque', 'british', 'classic', 'rock', 'psychedelic', 'merseybeat', 'invasion'}
# {'dance', 'pop'}
# {'stomp', 'pop', 'rock', 'modern', 'welsh', 'alternative'}
# {'pov', 'indie'}
# {'metal', 'wave', 'rock', 'funk', 'alternative', 'permanent'}
# {'indie', 'blues', 'punk', 'rock', 'modern', 'pov', 'alternative'}
# {'sound', 'country', 'singersongwriter', 'nashville', 'classic', 'outlaw', 'pop', 'rock', 'texas'}
# {'sound', 'country', 'singersongwriter', 'nashville', 'classic', 'outlaw', 'pop', 'rock', 'texas'}
# {'sound', 'country', 'singersongwriter', 'nashville', 'classic', 'outlaw', 'pop', 'rock', 'texas'}
# {'sound', 'country', 'singersongwriter', 'nashville', 'classic', 'outlaw', 'pop', 'rock', 'texas'}
# {'modern', 'southern', 'rock'}
# {'country', 'road', 'contemporary', 'rock', 'modern'}
# {'country', 'road', 'contemporary', 'outlaw'}
# {'country'}
# {'country', 'outlaw', 'redneck'}

# %%
#check_df['All_text'] = check_df.track_track_name.str.cat(" " + check_df.artist_genre)
check_df['All_text'] = check_df.artist_genre
check_df
# Out:
#       track_artist_name                       track_track_uri  \
# 0         Missy Elliott  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1        Britney Spears  spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 2               Beyoncé  spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 3     Justin Timberlake  spotify:track:1AWQoqb9bSvzTjaLralEkT
# 4                Shaggy  spotify:track:1lzr43nnXAijIGYnCT8M8H
# ..                  ...                                   ...
# 517  The Cadillac Three  spotify:track:4YZFC2igC3mzuktFHSF9mY
# 518          Chris Lane  spotify:track:17Vry8h1fUTYg8NL6pHhem
# 519        Travis Tritt  spotify:track:3oW6SWwGqiZSPTiAp7ZQoH
# 520        Alan Jackson  spotify:track:2LbOTztU3giUjjYmgtKgj3
# 521  Wheeler Walker Jr.  spotify:track:0nJzekxLI0x35YtKg0FdZ2
#
#                                track_track_name  \
# 0    Lose Control (feat. Ciara & Fat Man Scoop)
# 1                                         Toxic
# 2                                 Crazy In Love
# 3                                Rock Your Body
# 4                                  It Wasn't Me
# ..                                          ...
# 517                              Drunk Like You
# 518                                         Fix
# 519                It's A Great Day To Be Alive
# 520                Chattahoochee - Extended Mix
# 521                    Eatin' Pussy/Kickin' Ass
#
#                                  track_album_name playlist_name playlist_pid  \
# 0                                    The Cookbook    Throwbacks            0
# 1                                     In The Zone    Throwbacks            0
# 2    Dangerously In Love (Alben für die Ewigkeit)    Throwbacks            0
# 3                                       Justified    Throwbacks            0
# 4                                        Hot Shot    Throwbacks            0
# ..                                            ...           ...          ...
# 517                           Bury Me In My Boots  old country             9
# 518                                 Girl Problems  old country             9
# 519                            Down The Road I Go  old country             9
# 520                               16 Biggest Hits  old country             9
# 521                                  Redneck Shit  old country             9
#
#     playlist_description  danceability  energy  key  ...  liveness  valence  \
# 0                    NaN         0.904   0.813    4  ...    0.0471    0.810
# 1                    NaN         0.774   0.838    5  ...    0.2420    0.924
# 2                    NaN         0.664   0.758    2  ...    0.0598    0.701
# 3                    NaN         0.892   0.714    4  ...    0.0521    0.817
# 4                    NaN         0.853   0.606    0  ...    0.3130    0.654
# ..                   ...           ...     ...  ...  ...       ...      ...
# 517                  NaN         0.543   0.793    0  ...    0.3630    0.553
# 518                  NaN         0.532   0.883    0  ...    0.3040    0.700
# 519                  NaN         0.595   0.653    7  ...    0.2640    0.542
# 520                  NaN         0.579   0.801    0  ...    0.0821    0.972
# 521                  NaN         0.586   0.848   11  ...    0.1220    0.645
#
#        tempo  duration_ms  time_signature  song_popularity  \
# 0    125.461       226864               4               69
# 1    143.040       198800               4               84
# 2     99.259       235933               4               21
# 3    100.972       267267               4               79
# 4     94.759       227600               4                4
# ..       ...          ...             ...              ...
# 517  140.060       208453               4               38
# 518   99.995       190240               4               59
# 519  128.930       241533               4               75
# 520  174.755       237267               4               56
# 521  137.723       191520               4               50
#
#                                           artist_genre  artist_popularity  \
# 0    dance urban hop hip virginia soul r&b pop cont...                 72
# 1                                            dance pop                 80
# 2                                              r&b pop                 87
# 3                                            dance pop                 79
# 4                          dance reggae pop fusion rap                 73
# ..                                                 ...                ...
# 517                               modern southern rock                 55
# 518              country road contemporary rock modern                 59
# 519                   country road contemporary outlaw                 64
# 520                                            country                 72
# 521                             country outlaw redneck                 56
#
#      album_popularity                                           All_text
# 0                  62  dance urban hop hip virginia soul r&b pop cont...
# 1                  78                                          dance pop
# 2                  17                                            r&b pop
# 3                  77                                          dance pop
# 4                   1                        dance reggae pop fusion rap
# ..                ...                                                ...
# 517                47                               modern southern rock
# 518                59              country road contemporary rock modern
# 519                69                   country road contemporary outlaw
# 520                61                                            country
# 521                56                             country outlaw redneck
#
# [522 rows x 24 columns]

# %%
# Imports
from sklearn.cluster import KMeans
from sklearn import metrics 
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# import nltk
# from nltk.stem import WordNetLemmatizer

# %%
# stopwords = nltk.corpus.stopwords.words('english')
# lemmatizer = WordNetLemmatizer()
# nltk.download('stopwords')

# %%
check_df.keys()
# Out:
# Index(['track_artist_name', 'track_track_uri', 'track_track_name',
#        'track_album_name', 'playlist_name', 'playlist_pid',
#        'playlist_description', 'danceability', 'energy', 'key', 'loudness',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature', 'song_popularity',
#        'artist_genre', 'artist_popularity', 'album_popularity', 'All_text'],
#       dtype='object')

# %%
song_features = ['danceability', 'energy', 'key', 'loudness',
       'speechiness', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo', 'song_popularity', 'artist_popularity', 'album_popularity']
df_song_features = check_df[song_features]

# %%
df_song_features
# Out:
#      danceability  energy  key  loudness  speechiness  acousticness  \
# 0           0.904   0.813    4    -7.105       0.1210       0.03110
# 1           0.774   0.838    5    -3.914       0.1140       0.02490
# 2           0.664   0.758    2    -6.583       0.2100       0.00238
# 3           0.892   0.714    4    -6.055       0.1410       0.20100
# 4           0.853   0.606    0    -4.596       0.0713       0.05610
# ..            ...     ...  ...       ...          ...           ...
# 517         0.543   0.793    0    -5.905       0.0403       0.22500
# 518         0.532   0.883    0    -2.743       0.0352       0.09510
# 519         0.595   0.653    7    -4.935       0.0265       0.24600
# 520         0.579   0.801    0    -7.454       0.0449       0.12100
# 521         0.586   0.848   11    -6.899       0.2970       0.03800
#
#      instrumentalness  liveness  valence    tempo  song_popularity  \
# 0            0.006970    0.0471    0.810  125.461               69
# 1            0.025000    0.2420    0.924  143.040               84
# 2            0.000000    0.0598    0.701   99.259               21
# 3            0.000234    0.0521    0.817  100.972               79
# 4            0.000000    0.3130    0.654   94.759                4
# ..                ...       ...      ...      ...              ...
# 517          0.000114    0.3630    0.553  140.060               38
# 518          0.000000    0.3040    0.700   99.995               59
# 519          0.000000    0.2640    0.542  128.930               75
# 520          0.000076    0.0821    0.972  174.755               56
# 521          0.000640    0.1220    0.645  137.723               50
#
#      artist_popularity  album_popularity
# 0                   72                62
# 1                   80                78
# 2                   87                17
# 3                   79                77
# 4                   73                 1
# ..                 ...               ...
# 517                 55                47
# 518                 59                59
# 519                 64                69
# 520                 72                61
# 521                 56                56
#
# [522 rows x 13 columns]

# %%
song_features_array = np.array(df_song_features)

# %%
from sklearn.decomposition import TruncatedSVD

# %%
vectorizer = TfidfVectorizer(stop_words='english')

X_train = vectorizer.fit_transform(string_field)
print(X_train[0])
x_train_array = X_train.toarray()

svd = TruncatedSVD(n_components=1)
#print(type(svd))
text_X_train = svd.fit_transform(X_train)
#print(text_X_train)
#print(text_X_train.shape)

for index, value in enumerate(text_X_train):
    print(string_field[index], value)

print(text_X_train)
#print(x_train_array)
print(x_train_array.shape)
print(x_train_array[0][44])
f_xtrain_nosvp = np.concatenate((song_features_array, x_train_array), axis=1)
print('xtrain_nosvp', f_xtrain_nosvp.shape)
f_xtrain = np.concatenate((song_features_array, text_X_train), axis=1)
print(f_xtrain)
print(f_xtrain.shape)

#print(X_train)
#print(f"n_samples: {X_train.shape[0]}, n_features: {X_train.shape[1]}")
# Out:
#   (0, 160)	0.33064799790423094
#   (0, 204)	0.2344858895583595
#   (0, 52)	0.2795697500236954
#   (0, 187)	0.13422710385996092
#   (0, 26)	0.23574558407778073
#   (0, 210)	0.2423888486082042
#   (0, 236)	0.33064799790423094
#   (0, 266)	0.48388274154583755
#   (0, 110)	0.26690604703561915
#   (0, 112)	0.2708902786789246
#   (0, 262)	0.3071810358033194
#   (0, 55)	0.2067186453397504
# dance urban hop hip virginia soul rhythm blues pop contemporary rap neo [0.49038904]
# dance pop [0.72409486]
# rhythm blues pop [0.495341]
# dance pop [0.72409486]
# dance reggae pop fusion rap [0.40833619]
# carolina dance south urban hop hip rhythm blues pop contemporary rap atl [0.50498025]
# carolina dance south urban hop hip rhythm blues pop contemporary rap atl [0.50498025]
# carolina dance south urban hop hip rhythm blues pop contemporary rap atl [0.50498025]
# dance pop group girl [0.44806366]
# dance urban rhythm blues pop contemporary group girl [0.51926163]
# old atlanta south hop hip dirty school southern rap atl [0.13890203]
# latin canadian dance pop [0.31831886]
# dance pop postteen [0.44902397]
# dance pop postteen [0.44902397]
# dance pop postteen [0.44902397]
# dance urban hip rhythm blues pop contemporary rap [0.63430345]
# dance urban hop hip southern rhythm blues pop trap contemporary rap [0.51136411]
# canadian pop candy [0.1783492]
# rhythm blues rap [0.41687519]
# rhythm blues pop [0.495341]
# dance urban rhythm blues pop contemporary group girl [0.51926163]
# lilith wave singersongwriter pop rock new permanent [0.20483418]
# dance pop rap [0.74278583]
# neon texas pop punk [0.16838829]
# neon pixie pop punk band boy [0.15926841]
# rhythm blues rap [0.41687519]
# boy pop band [0.22161137]
# hip queen pop trap [0.17347321]
# melbourne techno bounce eurodance international german europop [0.00342094]
# dance pop [0.72409486]
# dance urban rhythm blues pop contemporary [0.56587755]
# pop [0.61753223]
# pop [0.61753223]
# neon pop punk [0.21121398]
# neon pop punk [0.21121398]
# dance pop rap postteen [0.54466746]
# rhythm blues rap [0.41687519]
# rhythm blues rap [0.41687519]
# dance pop [0.72409486]
# dance urban rhythm blues pop contemporary [0.56587755]
# canadian pop [0.2714586]
# neosynthpop rave room escape new indietronica [0.02280954]
# dance wave rock modern alternative permanent [0.32512113]
# metal pop punk rock socal modern alternative [0.2452567]
# dance pop group girl [0.44806366]
# canadian pop [0.2714586]
# neon metal postgrunge mellow pop punk rock modern alternative neo [0.2525123]
# canadian pop [0.2714586]
# piano lilith mellow postteen pop rock neo [0.20893984]
# indie rap pop [0.52402563]
# pop [0.61753223]
# dance pop postteen [0.44902397]
# pop postteen [0.26531035]
# canadian pop candy [0.1783492]
# neon piano pop punk rock [0.20535318]
# neon pop punk [0.21121398]
# neon pop punk [0.21121398]
# metal hard glam soft album rock [0.06683181]
# scorecore [-1.05098349e-05]
# scorecore [-1.05098349e-05]
# scorecore [-1.05098349e-05]
# scorecore [-1.05098349e-05]
# scorecore [-1.05098349e-05]
# scorecore [-1.05098349e-05]
# scorecore [-1.05098349e-05]
# british soundtrack [0.00676865]
# vocal broadway jazz show tunes [0.00153667]
# show movie tunes broadway [4.27941888e-05]
# vocal broadway jazz show tunes [0.00153667]
# show tunes broadway [5.48228421e-05]
# hard album rock classic [0.08149747]
# grunge alternative pop rock postgrunge [0.23281644]
# fantasy power metal symphonic gothic opera finnish [0.01483352]
# british soul [0.0264048]
# british classic album rock invasion [0.06784194]
# british classic album rock invasion [0.06784194]
# hard classic southern album rock [0.07459271]
# metal hard mellow glam gold classic soft album rock [0.07692923]
# metal hard mellow glam gold classic soft album rock [0.07692923]
# hard yacht mellow gold classic soft album rock [0.06798084]
# progressive hard mellow gold classic soft album rock heartland [0.06897333]
# glam rock classic [0.07100173]
# hard classic southern album rock [0.07459271]
# metal hard mellow glam gold classic soft album rock [0.07692923]
# hard album rock classic [0.08149747]
# british soundtrack [0.00676865]
# hard glam rock metal [0.0720458]
# swamp country classic southern rock [0.05988968]
# metal hard album german rock [0.06639582]
# progressive metal hard classic album rock canadian [0.08796749]
# progressive metal hard classic album rock canadian [0.08796749]
# progressive metal hard classic album rock canadian [0.08796749]
# progressive metal hard classic album rock canadian [0.08796749]
# progressive metal hard classic album rock canadian [0.08796749]
# progressive metal hard classic album rock canadian [0.08796749]
# progressive metal hard classic album rock canadian [0.08796749]
# korean rhythm blues [0.28235823]
# rhythm blues korean krap kpop [0.30925583]
# korean pop [0.34297424]
# korean pop [0.34297424]
# boy pop group kpop [0.36643282]
# girl group kpop [0.19323088]
# kpop [0.19554366]
# kpop [0.19554366]
# kpop [0.19554366]
# kpop [0.19554366]
# rhythm blues korean krap kpop [0.30925583]
# rhythm blues korean krap kpop [0.30925583]
# kpop [0.19554366]
# kpop [0.19554366]
# rhythm blues korean krap kpop [0.30925583]
#  [0.]
# rhythm blues korean krap kpop [0.30925583]
# rhythm blues korean krap kpop [0.30925583]
# rhythm blues korean krap kpop [0.30925583]
# korean rhythm blues kpop [0.3409649]
# kpop [0.19554366]
# kpop [0.19554366]
# rhythm blues korean krap kpop [0.30925583]
# boy pop group kpop [0.36643282]
# pop girl group kpop [0.34384251]
# korean pop singersongwriter kpop [0.31431257]
# korean pop [0.34297424]
# korean pop [0.34297424]
# boy group kpop [0.21004393]
# boy group kpop [0.21004393]
# rhythm blues korean krap kpop [0.30925583]
# girl group kpop [0.19323088]
# girl group kpop [0.19323088]
# kpop [0.19554366]
# kpop [0.19554366]
# kpop [0.19554366]
# ost korean jdivision [0.04232374]
# boy group kpop [0.21004393]
# boy group kpop [0.21004393]
# korean rhythm blues [0.28235823]
# pop girl group kpop [0.34384251]
# krap kpop [0.15022327]
# krap kpop [0.15022327]
# korean rhythm blues kpop [0.3409649]
# korean rhythm blues kpop [0.3409649]
# kpop [0.19554366]
# pop girl group kpop [0.34384251]
# boy pop group kpop [0.36643282]
# boy group kpop [0.21004393]
# kpop [0.19554366]
# kpop [0.19554366]
# kpop [0.19554366]
# boy group kpop [0.21004393]
# korean pop [0.34297424]
# rhythm blues korean krap kpop [0.30925583]
# boy pop group kpop [0.36643282]
#  [0.]
# boy group kpop [0.21004393]
# kpop [0.19554366]
# kpop [0.19554366]
# boy pop group kpop [0.36643282]
# boy pop group kpop [0.36643282]
# boy pop group kpop [0.36643282]
# boy pop group kpop [0.36643282]
# era classical romanticism romantic late french [0.0041696]
# era classical romanticism romantic late french [0.0041696]
# indie garage surf pop rock pov [0.23517001]
# indie garage surf pop rock pov [0.23517001]
# bedroom pop [0.20428932]
# bedroom pop [0.20428932]
# queercore [2.68304041e-10]
# synthpop romantic wave sophistipop pop rock new permanent [0.1646936]
#  [0.]
# garage pov indie rock [0.14062301]
# garage pov indie rock [0.14062301]
# garage pov indie rock [0.14062301]
# indie hypnagogic garage pop rock [0.25083076]
# indie hypnagogic garage pop rock [0.25083076]
# indie hypnagogic garage pop rock [0.25083076]
# indie hypnagogic garage pop rock [0.25083076]
# uk pop alternative [0.2702696]
# indie rock australian [0.13558469]
# brooklyn neopsychedelic indie nu dreamo surf shoegaze dream pop rock gaze modern [0.14594468]
#  [0.]
# seattle bubblegrunge powerpop indie surf riot punk grrrl [0.03386312]
# modern pop power [0.26364531]
# piano indie rock washington [0.07935899]
# modern pop power [0.26364531]
# dance neosynthpop rave indie indietronica rock modern new dancepunk alternative [0.21225316]
# countrygaze bubblegrunge indie alabama pop rock chamber [0.15132589]
# brooklyn weird art neosynthpop indie america pop rock new baroque alternative [0.17558781]
# brooklyn weird art neosynthpop indie america pop rock new baroque alternative [0.17558781]
# holler modern and indie garage stomp pop rock chamber baroque indietronica [0.24057211]
# indie garage pop rock noise [0.27238525]
# holler and indie nashville shimmer stomp pop [0.17707748]
# modern pop rock alternative [0.40274324]
# holler folk philly modern and indie pov stomp pop rock chamber [0.21337149]
# holler and indie melancholia jam louisville roots stomp pop rock band chamber [0.13950264]
# brooklyn nyc indie shimmer pop electropop poptimism [0.14333148]
# brooklyn nyc indie shimmer pop electropop poptimism [0.14333148]
# afrofuturism [-4.2405696e-11]
# boy rap band [0.19147043]
# boy rap band [0.19147043]
#  [0.]
# hop hip underground [0.09789139]
# hop hip underground [0.09789139]
# aesthetic hop ottawa hip trap cloud canadian dark rap [0.1281595]
# pov indie pop experimental [0.23200948]
# pov indie pop experimental [0.23200948]
# pov indie pop experimental [0.23200948]
# ambient indie paso el shoegaze dream pop [0.11663984]
# ambient indie paso el shoegaze dream pop [0.11663984]
# pov lofi indie emo [0.05444314]
# tulsa indie [0.03861261]
# indie garage rock modern brighton [0.14039627]
# art grave wave indie pop dream area rock bay noise experimental [0.17023925]
# shoegaze [0.00648273]
# shoegaze [0.00648273]
# shoegaze [0.00648273]
# shoegaze [0.00648273]
# shoegaze [0.00648273]
# holler chamber and indie oakland stomp pop area rock bay noise [0.17747271]
# holler chamber and indie oakland stomp pop area rock bay noise [0.17747271]
# holler chamber and indie oakland stomp pop area rock bay noise [0.17747271]
# holler chamber and indie oakland stomp pop area rock bay noise [0.17747271]
# holler chamber and indie oakland stomp pop area rock bay noise [0.17747271]
# power wave pop rock modern alternative permanent [0.27824978]
# lofi rap [0.17298511]
# lofi rap [0.17298511]
# lofi rap [0.17298511]
# brooklyn neosynthpop metropopolis indie indietronica [0.04890803]
# neopsychedelic kiwi pop rock experimental [0.15954183]
# grunge metal postgrunge pop rock alternative [0.22436113]
# francais rock independant [0.03818]
# dance pop contemporary urban [0.48928527]
# dance pop contemporary urban [0.48928527]
# russian shoegaze dream pop modern [0.15724137]
# rock alternative [0.16736673]
# urban swing rhythm blues contemporary group jack new girl [0.21840582]
# nz indie dreamo [0.03010406]
# bedroom pop [0.20428932]
# synthpop dance romantic wave zolo rock new [0.18497592]
# synthpop dance romantic wave zolo rock new [0.18497592]
# synthpop dance romantic wave zolo rock new [0.18497592]
# synthpop dance romantic wave zolo rock new [0.18497592]
# synthpop dance romantic wave zolo rock new [0.18497592]
# countrygaze lofi indie slowcore room pov small emo [0.03752175]
# modern dream pop [0.24489355]
# art indie singersongwriter pop rock chamber baroque [0.2224552]
# chillwave art pop metropopolis [0.15460939]
# chillwave art pop metropopolis [0.15460939]
# yacht rock [0.05963823]
# hardcore power postpunk pop punk rock posthardcore noise experimental alternative [0.18017404]
# hardcore power postpunk pop punk rock posthardcore noise experimental alternative [0.18017404]
# hardcore power postpunk pop punk rock posthardcore noise experimental alternative [0.18017404]
# hardcore power postpunk pop punk rock posthardcore noise experimental alternative [0.18017404]
# hardcore power postpunk pop punk rock posthardcore noise experimental alternative [0.18017404]
# mod wave new revival [0.0259175]
#  [0.]
# room small [0.00481319]
# room small [0.00481319]
# mod revival [0.0005313]
#  [0.]
# krautrock [5.29965179e-10]
# bluesrock psychedelic [0.00289456]
# hop hip conscious uk alternative [0.12924239]
# hardcore hop hip coast east [0.08604323]
# jersey hop hip conscious coast east new rap [0.14577075]
#  [0.]
#  [0.]
# bay indie area [0.04820894]
# chicago garage indie rock [0.10787509]
# chicago garage indie rock [0.10787509]
# pov indie [0.08630535]
# pov indie [0.08630535]
# soul rhythm blues indie alternative [0.25970509]
# british soul psychedelic neo [0.04301341]
# vocal blues soul jazz song torch [0.0618276]
# indie punk orgcore posthardcore emo [0.04359033]
# chicago hardcore punk posthardcore [0.02997639]
# chicago hardcore punk posthardcore [0.02997639]
# chicago hardcore punk posthardcore [0.02997639]
# lofi indie newfoundland room small [0.03200906]
# mn indie bedroom pop rochester [0.13259194]
#  [0.]
# indie rock pinoy [0.08570961]
# ambient folk [0.00952893]
# garage indie rock [0.14730014]
# wave no postpunk egg punk rock experimental [0.07369403]
# garage neopsychedelic indie rock [0.10723435]
# grunge spacegrunge metal wave rock alternative permanent [0.10206742]
# beatlesque wave madchester britpop rock permanent [0.05997309]
# hard album rock classic [0.08149747]
# lilith folk singersongwriter ectofolk [0.02820237]
# dance urban hop hip rhythm blues pop contemporary group atl girl [0.49980431]
# grunge spacegrunge metal wave rock alternative permanent [0.10206742]
# lilith dance wave pop rock new europop [0.31295456]
# lilith pop rock [0.27864948]
# dance urban rhythm blues pop contemporary [0.56587755]
# lilith wave singersongwriter ectofolk pop rock canadian permanent [0.1815585]
# wave shoegaze britpop rock permanent [0.07180706]
# grunge postgrunge wave pop rock alternative permanent [0.22163866]
# postgrunge pop rock [0.27559919]
# lilith dance mellow pop rock europop neo [0.3165147]
# british soul sophistipop [0.02040541]
#  [0.]
# postgrunge pop rock heartland [0.20460327]
# pop rap [0.58149345]
# pop [0.61753223]
# pop [0.61753223]
# dance pop rap [0.74278583]
# hop miami hip [0.14241538]
# motown classic soul storm funk quiet [0.02069428]
# dance hop hip miami pop rap [0.51981146]
# dance pop rap [0.74278583]
# dance pop rap [0.74278583]
# carolina dance south urban hop hip rhythm blues pop contemporary rap atl [0.50498025]
# soul rhythm blues [0.22370149]
# old school hop hip [0.08357998]
# carolina dance south urban hop hip rhythm blues pop contemporary rap atl [0.50498025]
# carolina dance south urban hop hip rhythm blues pop contemporary rap atl [0.50498025]
# dance pop [0.72409486]
# dance party kids [0.14813237]
# folk building mellow gold yacht singersongwriter adult soft pop rock standards brill heartland [0.10279404]
# dance party kids [0.14813237]
# art pop dance [0.47043074]
# art pop dance [0.47043074]
# melbourne techno bounce eurodance international german europop [0.00342094]
# house electro filter rock [0.04092981]
# art pop dance [0.47043074]
# art pop dance [0.47043074]
# dance hop hip miami pop rap [0.51981146]
# dance hop hip miami pop [0.43330553]
# dance pop rap [0.74278583]
# urban pop contemporary barbadian [0.21884697]
# dance mellow pop rock neo [0.43237795]
# rhythm blues rap [0.41687519]
# rhythm blues rap [0.41687519]
# hop hip pop queens rap [0.32157133]
# vocal blues soul jazz song torch [0.0618276]
# disco rock funk [0.05250112]
#  [0.]
# soul rhythm blues [0.22370149]
# dance pop rap [0.74278583]
# dance pop rap [0.74278583]
# hop hip pop rap [0.45756662]
# soul rhythm blues [0.22370149]
# reggae roots [0.00960862]
# dance pop [0.72409486]
# uk pop [0.26388664]
# dance pop [0.72409486]
# mellow pop rock neo [0.27573482]
# dance mellow pop acoustic neo [0.30519932]
# lilith pop rock [0.27864948]
# modern pop rock [0.43662815]
# modern pop rock [0.43662815]
# rhythm blues contemporary urban [0.28969606]
# british rock alternative [0.1208749]
# mellow dance pop neo [0.40092765]
# rhythm blues pop [0.495341]
# mellow jam pop band rock neo [0.18742789]
# dance pop rap [0.74278583]
# dance pop rap [0.74278583]
# pop [0.61753223]
# country road contemporary [0.06879889]
# country road contemporary [0.06879889]
# country road contemporary [0.06879889]
# country road contemporary [0.06879889]
# country road contemporary [0.06879889]
# country road contemporary [0.06879889]
# hard mellow gold singersongwriter classic soft album rock heartland [0.07279928]
# dance pop rap [0.74278583]
# dance dutch brostep trance house slap big room pop edm [0.1757273]
# dance dutch brostep trance house slap big room pop edm [0.1757273]
# dance pop rap [0.74278583]
# dance pop rap [0.74278583]
# folkpop holler mellow and stomp rock modern neo [0.12373723]
# dance hop hip miami pop rap [0.51981146]
# dance hop hip miami pop rap [0.51981146]
# dance hop hip miami pop rap [0.51981146]
# hop hip coast rock west gangster rap [0.1789605]
# old atlanta hardcore hop hip school pop gangster rap [0.21250746]
# sound minneapolis urban swing rhythm blues contemporary band jack boy new [0.16714786]
# dance dutch brostep trance house slap big room pop edm [0.1757273]
# dance dutch brostep trance house slap big room pop edm [0.1757273]
# rhythm blues rap [0.41687519]
# rhythm blues rap [0.41687519]
# modern pop rock [0.43662815]
# modern pop rock [0.43662815]
# country road pop contemporary rock modern [0.27554217]
# rhythm blues rap [0.41687519]
# uk pop dance funky [0.33073591]
# pop postteen [0.26531035]
# art metropopolis candy pop uk [0.16105411]
# progressive dance house electro pop edm uk [0.22888969]
# urbano reggaeton latin latina latino pop viral rap [0.13864999]
# pop [0.61753223]
# seattle hop hip pop rap [0.34116257]
# dance hop hip miami pop [0.43330553]
#  [0.]
# swamp country classic southern rock [0.05988968]
# indietronica indie rock [0.13004764]
# metal reggae nu pop rock funk fusion rap alternative [0.25763776]
# holler folk and indie blues stomp rock modern new americana [0.1719949]
# postgrunge grunge rock alternative [0.1018063]
# stoner grunge scene metal nu rock modern desert alternative palm [0.07996111]
# pop rock irish [0.22502037]
# hardcore jersey horror punk new [0.03082074]
# hardcore jersey horror punk new [0.03082074]
# hardcore jersey horror punk new [0.03082074]
# shimmer pop [0.22269306]
# postgrunge [0.02237895]
# neopsychedelic psych rock australian modern [0.09164601]
# dance pop australian [0.45243615]
# dance pop australian [0.45243615]
# wave indie garage rock modern sheffield permanent [0.14131587]
# folk indie [0.05841138]
# holler folk and indie singersongwriter stomp pop chamber irish [0.15874703]
# z brooklyn alt metropopolis nyc vapor indie pop electropop dark poptimism [0.10770858]
# canadian rhythm blues contemporary [0.25310154]
# aussietronica [0.00271498]
# metropopolis indietronica [0.02331864]
# z electropop alt [0.00755397]
# reggae fusion australian [0.03413862]
# etherpop electropop indie [0.04063537]
# z electropop alt [0.00755397]
# pov electropop indie poptimism [0.06167444]
# art indie shimmer indietronica pop electropop poptimism [0.17068063]
# dance hop hip coast pop east rap [0.40153487]
# downtempo dance indie australian edm electropop indietronica [0.16563951]
#  [0.]
# indie pop etherpop electropop poptimism [0.15182796]
# nyc pop [0.21435199]
# australian brisbane indie aussietronica [0.04812668]
# australian brisbane indie aussietronica [0.04812668]
# metropopolis nottingham indie [0.03710323]
# hop hip rap atl [0.24928038]
# pop la [0.19196356]
#  [0.]
#  [0.]
# soul indie electronica [0.04846287]
# modern britpop welsh rock [0.09898949]
#  [0.]
# dance pop uk funky [0.33073591]
# british rock alternative [0.1208749]
# holler folk and indie stomp pop australian acoustic [0.16863673]
#  [0.]
# dutch pop [0.20515807]
# devotional world [-2.00209463e-10]
# pop norwegian [0.16882507]
# downtempo hop hip electronica nu jazztronica jazz instrumental indietronica trip [0.05512628]
# british soul [0.0264048]
# downtempo art indie shimmer soul pop indietronica [0.17153976]
# anthemfolk indie [0.03861261]
# australian brisbane indie aussietronica [0.04812668]
# australian brisbane indie aussietronica [0.04812668]
# vapor rhythm blues soul neo [0.16661524]
#  [0.]
# shimmer pop [0.22269306]
#  [0.]
# dance pop [0.72409486]
# dance pop uk funky [0.33073591]
# dance house edm uk indietronica [0.16833511]
# pop australian [0.25845943]
# detroit hop hip southern rhythm blues trap queen rap [0.23379537]
# neosynthpop metropopolis nyc indie pop hopebeat poptimism [0.12730197]
# nyc pop [0.21435199]
# metropopolis indietronica [0.02331864]
# indie australian [0.07962595]
# pop viral [0.18026991]
# dancefloor liquid bass and drum funk dnb [0.00505711]
# stomp pop rock modern welsh alternative [0.27908018]
# stomp pop rock modern welsh alternative [0.27908018]
# indie pov blues punk rock modern alternative [0.26238903]
# metal wave rock funk alternative permanent [0.12405202]
# metal reggae nu pop rock funk fusion rap alternative [0.25763776]
# indie garage rock modern brighton [0.14039627]
# piano holler and indie stomp rock modern alternative [0.16647768]
# piano holler and indie stomp rock modern alternative [0.16647768]
# modern rock [0.19493602]
# mellow pop rock modern uk baroque alternative neo [0.26685127]
# mellow pop rock modern uk baroque alternative neo [0.26685127]
# beatlesque british classic rock psychedelic merseybeat invasion [0.05166431]
# modern rock [0.19493602]
# metal wave rock funk alternative permanent [0.12405202]
# metal wave rock funk alternative permanent [0.12405202]
# wave punk rock modern permanent [0.15271065]
# wave punk rock modern permanent [0.15271065]
# holler folk and indie stomp rock modern [0.14960297]
# beatlesque british classic rock psychedelic merseybeat invasion [0.05166431]
# indie indietronica rock modern alternative [0.19722484]
# indie indietronica rock modern alternative [0.19722484]
# stomp pop rock modern welsh alternative [0.27908018]
# la indie pov rock modern alternative [0.16759609]
# beatlesque british classic rock psychedelic merseybeat invasion [0.05166431]
# beatlesque british classic rock psychedelic merseybeat invasion [0.05166431]
# hop hip rock modern alternative [0.25161147]
# holler modern and indie garage stomp pop rock chamber baroque indietronica [0.24057211]
# beatlesque british classic rock psychedelic merseybeat invasion [0.05166431]
# art beatlesque symphonic mellow glam gold classic soft album rock [0.07290804]
# reggae fusion rock [0.06413971]
# mellow pop rock modern uk baroque alternative neo [0.26685127]
# metal wave rock funk alternative permanent [0.12405202]
# la indie pov rock modern alternative [0.16759609]
# metal wave rock funk alternative permanent [0.12405202]
# reggae fusion uk [0.03722207]
# beatlesque british classic rock psychedelic merseybeat invasion [0.05166431]
# seattle modern indie indietronica pop rock chamber alternative washington [0.2233648]
# metal wave rock funk alternative permanent [0.12405202]
# beatlesque british classic rock psychedelic merseybeat invasion [0.05166431]
# folk beatlesque mellow gold sunshine singersongwriter classic bubblegum soft pop album rock heartland rockandroll [0.11587691]
# beatlesque british classic rock psychedelic merseybeat invasion [0.05166431]
# dance pop [0.72409486]
# stomp pop rock modern welsh alternative [0.27908018]
# pov indie [0.08630535]
# metal wave rock funk alternative permanent [0.12405202]
# indie pov blues punk rock modern alternative [0.26238903]
# sound country singersongwriter classic nashville outlaw pop rock texas [0.14125445]
# sound country singersongwriter classic nashville outlaw pop rock texas [0.14125445]
# sound country singersongwriter classic nashville outlaw pop rock texas [0.14125445]
# sound country singersongwriter classic nashville outlaw pop rock texas [0.14125445]
# modern southern rock [0.13055085]
# country road contemporary rock modern [0.15047755]
# country road contemporary outlaw [0.0600632]
# country [0.01766154]
# country outlaw redneck [0.01179507]
# [[ 4.90389038e-01]
#  [ 7.24094856e-01]
#  [ 4.95341003e-01]
#  [ 7.24094856e-01]
#  [ 4.08336187e-01]
#  [ 5.04980248e-01]
#  [ 5.04980248e-01]
#  [ 5.04980248e-01]
#  [ 4.48063665e-01]
#  [ 5.19261630e-01]
#  [ 1.38902033e-01]
#  [ 3.18318858e-01]
#  [ 4.49023970e-01]
#  [ 4.49023970e-01]
#  [ 4.49023970e-01]
#  [ 6.34303447e-01]
#  [ 5.11364106e-01]
#  [ 1.78349199e-01]
#  [ 4.16875190e-01]
#  [ 4.95341003e-01]
#  [ 5.19261630e-01]
#  [ 2.04834178e-01]
#  [ 7.42785830e-01]
#  [ 1.68388287e-01]
#  [ 1.59268414e-01]
#  [ 4.16875190e-01]
#  [ 2.21611371e-01]
#  [ 1.73473211e-01]
#  [ 3.42093539e-03]
#  [ 7.24094856e-01]
#  [ 5.65877554e-01]
#  [ 6.17532228e-01]
#  [ 6.17532228e-01]
#  [ 2.11213983e-01]
#  [ 2.11213983e-01]
#  [ 5.44667461e-01]
#  [ 4.16875190e-01]
#  [ 4.16875190e-01]
#  [ 7.24094856e-01]
#  [ 5.65877554e-01]
#  [ 2.71458604e-01]
#  [ 2.28095404e-02]
#  [ 3.25121130e-01]
#  [ 2.45256701e-01]
#  [ 4.48063665e-01]
#  [ 2.71458604e-01]
#  [ 2.52512305e-01]
#  [ 2.71458604e-01]
#  [ 2.08939841e-01]
#  [ 5.24025626e-01]
#  [ 6.17532228e-01]
#  [ 4.49023970e-01]
#  [ 2.65310354e-01]
#  [ 1.78349199e-01]
#  [ 2.05353180e-01]
#  [ 2.11213983e-01]
#  [ 2.11213983e-01]
#  [ 6.68318135e-02]
#  [-1.05098349e-05]
#  [-1.05098349e-05]
#  [-1.05098349e-05]
#  [-1.05098349e-05]
#  [-1.05098349e-05]
#  [-1.05098349e-05]
#  [-1.05098349e-05]
#  [ 6.76864927e-03]
#  [ 1.53666558e-03]
#  [ 4.27941888e-05]
#  [ 1.53666558e-03]
#  [ 5.48228421e-05]
#  [ 8.14974747e-02]
#  [ 2.32816436e-01]
#  [ 1.48335157e-02]
#  [ 2.64048014e-02]
#  [ 6.78419393e-02]
#  [ 6.78419393e-02]
#  [ 7.45927089e-02]
#  [ 7.69292292e-02]
#  [ 7.69292292e-02]
#  [ 6.79808416e-02]
#  [ 6.89733288e-02]
#  [ 7.10017292e-02]
#  [ 7.45927089e-02]
#  [ 7.69292292e-02]
#  [ 8.14974747e-02]
#  [ 6.76864927e-03]
#  [ 7.20458033e-02]
#  [ 5.98896835e-02]
#  [ 6.63958170e-02]
#  [ 8.79674860e-02]
#  [ 8.79674860e-02]
#  [ 8.79674860e-02]
#  [ 8.79674860e-02]
#  [ 8.79674860e-02]
#  [ 8.79674860e-02]
#  [ 8.79674860e-02]
#  [ 2.82358233e-01]
#  [ 3.09255830e-01]
#  [ 3.42974245e-01]
#  [ 3.42974245e-01]
#  [ 3.66432819e-01]
#  [ 1.93230878e-01]
#  [ 1.95543656e-01]
#  [ 1.95543656e-01]
#  [ 1.95543656e-01]
#  [ 1.95543656e-01]
#  [ 3.09255830e-01]
#  [ 3.09255830e-01]
#  [ 1.95543656e-01]
#  [ 1.95543656e-01]
#  [ 3.09255830e-01]
#  [ 0.00000000e+00]
#  [ 3.09255830e-01]
#  [ 3.09255830e-01]
#  [ 3.09255830e-01]
#  [ 3.40964898e-01]
#  [ 1.95543656e-01]
#  [ 1.95543656e-01]
#  [ 3.09255830e-01]
#  [ 3.66432819e-01]
#  [ 3.43842513e-01]
#  [ 3.14312565e-01]
#  [ 3.42974245e-01]
#  [ 3.42974245e-01]
#  [ 2.10043933e-01]
#  [ 2.10043933e-01]
#  [ 3.09255830e-01]
#  [ 1.93230878e-01]
#  [ 1.93230878e-01]
#  [ 1.95543656e-01]
#  [ 1.95543656e-01]
#  [ 1.95543656e-01]
#  [ 4.23237427e-02]
#  [ 2.10043933e-01]
#  [ 2.10043933e-01]
#  [ 2.82358233e-01]
#  [ 3.43842513e-01]
#  [ 1.50223269e-01]
#  [ 1.50223269e-01]
#  [ 3.40964898e-01]
#  [ 3.40964898e-01]
#  [ 1.95543656e-01]
#  [ 3.43842513e-01]
#  [ 3.66432819e-01]
#  [ 2.10043933e-01]
#  [ 1.95543656e-01]
#  [ 1.95543656e-01]
#  [ 1.95543656e-01]
#  [ 2.10043933e-01]
#  [ 3.42974245e-01]
#  [ 3.09255830e-01]
#  [ 3.66432819e-01]
#  [ 0.00000000e+00]
#  [ 2.10043933e-01]
#  [ 1.95543656e-01]
#  [ 1.95543656e-01]
#  [ 3.66432819e-01]
#  [ 3.66432819e-01]
#  [ 3.66432819e-01]
#  [ 3.66432819e-01]
#  [ 4.16959927e-03]
#  [ 4.16959927e-03]
#  [ 2.35170015e-01]
#  [ 2.35170015e-01]
#  [ 2.04289322e-01]
#  [ 2.04289322e-01]
#  [ 2.68304041e-10]
#  [ 1.64693602e-01]
#  [ 0.00000000e+00]
#  [ 1.40623006e-01]
#  [ 1.40623006e-01]
#  [ 1.40623006e-01]
#  [ 2.50830760e-01]
#  [ 2.50830760e-01]
#  [ 2.50830760e-01]
#  [ 2.50830760e-01]
#  [ 2.70269601e-01]
#  [ 1.35584686e-01]
#  [ 1.45944678e-01]
#  [ 0.00000000e+00]
#  [ 3.38631171e-02]
#  [ 2.63645309e-01]
#  [ 7.93589883e-02]
#  [ 2.63645309e-01]
#  [ 2.12253161e-01]
#  [ 1.51325892e-01]
#  [ 1.75587814e-01]
#  [ 1.75587814e-01]
#  [ 2.40572110e-01]
#  [ 2.72385247e-01]
#  [ 1.77077475e-01]
#  [ 4.02743240e-01]
#  [ 2.13371486e-01]
#  [ 1.39502637e-01]
#  [ 1.43331480e-01]
#  [ 1.43331480e-01]
#  [-4.24056960e-11]
#  [ 1.91470433e-01]
#  [ 1.91470433e-01]
#  [ 0.00000000e+00]
#  [ 9.78913886e-02]
#  [ 9.78913886e-02]
#  [ 1.28159495e-01]
#  [ 2.32009483e-01]
#  [ 2.32009483e-01]
#  [ 2.32009483e-01]
#  [ 1.16639843e-01]
#  [ 1.16639843e-01]
#  [ 5.44431419e-02]
#  [ 3.86126091e-02]
#  [ 1.40396269e-01]
#  [ 1.70239249e-01]
#  [ 6.48272623e-03]
#  [ 6.48272623e-03]
#  [ 6.48272623e-03]
#  [ 6.48272623e-03]
#  [ 6.48272623e-03]
#  [ 1.77472713e-01]
#  [ 1.77472713e-01]
#  [ 1.77472713e-01]
#  [ 1.77472713e-01]
#  [ 1.77472713e-01]
#  [ 2.78249776e-01]
#  [ 1.72985108e-01]
#  [ 1.72985108e-01]
#  [ 1.72985108e-01]
#  [ 4.89080302e-02]
#  [ 1.59541827e-01]
#  [ 2.24361135e-01]
#  [ 3.81799954e-02]
#  [ 4.89285267e-01]
#  [ 4.89285267e-01]
#  [ 1.57241367e-01]
#  [ 1.67366731e-01]
#  [ 2.18405816e-01]
#  [ 3.01040643e-02]
#  [ 2.04289322e-01]
#  [ 1.84975917e-01]
#  [ 1.84975917e-01]
#  [ 1.84975917e-01]
#  [ 1.84975917e-01]
#  [ 1.84975917e-01]
#  [ 3.75217519e-02]
#  [ 2.44893547e-01]
#  [ 2.22455199e-01]
#  [ 1.54609386e-01]
#  [ 1.54609386e-01]
#  [ 5.96382349e-02]
#  [ 1.80174036e-01]
#  [ 1.80174036e-01]
#  [ 1.80174036e-01]
#  [ 1.80174036e-01]
#  [ 1.80174036e-01]
#  [ 2.59175034e-02]
#  [ 0.00000000e+00]
#  [ 4.81319344e-03]
#  [ 4.81319344e-03]
#  [ 5.31295193e-04]
#  [ 0.00000000e+00]
#  [ 5.29965179e-10]
#  [ 2.89455868e-03]
#  [ 1.29242393e-01]
#  [ 8.60432302e-02]
#  [ 1.45770751e-01]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 4.82089387e-02]
#  [ 1.07875093e-01]
#  [ 1.07875093e-01]
#  [ 8.63053489e-02]
#  [ 8.63053489e-02]
#  [ 2.59705087e-01]
#  [ 4.30134100e-02]
#  [ 6.18275952e-02]
#  [ 4.35903286e-02]
#  [ 2.99763900e-02]
#  [ 2.99763900e-02]
#  [ 2.99763900e-02]
#  [ 3.20090620e-02]
#  [ 1.32591943e-01]
#  [ 0.00000000e+00]
#  [ 8.57096090e-02]
#  [ 9.52892972e-03]
#  [ 1.47300142e-01]
#  [ 7.36940344e-02]
#  [ 1.07234349e-01]
#  [ 1.02067420e-01]
#  [ 5.99730886e-02]
#  [ 8.14974747e-02]
#  [ 2.82023710e-02]
#  [ 4.99804308e-01]
#  [ 1.02067420e-01]
#  [ 3.12954564e-01]
#  [ 2.78649481e-01]
#  [ 5.65877554e-01]
#  [ 1.81558499e-01]
#  [ 7.18070566e-02]
#  [ 2.21638664e-01]
#  [ 2.75599194e-01]
#  [ 3.16514699e-01]
#  [ 2.04054132e-02]
#  [ 0.00000000e+00]
#  [ 2.04603268e-01]
#  [ 5.81493450e-01]
#  [ 6.17532228e-01]
#  [ 6.17532228e-01]
#  [ 7.42785830e-01]
#  [ 1.42415383e-01]
#  [ 2.06942762e-02]
#  [ 5.19811457e-01]
#  [ 7.42785830e-01]
#  [ 7.42785830e-01]
#  [ 5.04980248e-01]
#  [ 2.23701495e-01]
#  [ 8.35799783e-02]
#  [ 5.04980248e-01]
#  [ 5.04980248e-01]
#  [ 7.24094856e-01]
#  [ 1.48132372e-01]
#  [ 1.02794043e-01]
#  [ 1.48132372e-01]
#  [ 4.70430743e-01]
#  [ 4.70430743e-01]
#  [ 3.42093539e-03]
#  [ 4.09298126e-02]
#  [ 4.70430743e-01]
#  [ 4.70430743e-01]
#  [ 5.19811457e-01]
#  [ 4.33305534e-01]
#  [ 7.42785830e-01]
#  [ 2.18846970e-01]
#  [ 4.32377952e-01]
#  [ 4.16875190e-01]
#  [ 4.16875190e-01]
#  [ 3.21571327e-01]
#  [ 6.18275952e-02]
#  [ 5.25011180e-02]
#  [ 0.00000000e+00]
#  [ 2.23701495e-01]
#  [ 7.42785830e-01]
#  [ 7.42785830e-01]
#  [ 4.57566616e-01]
#  [ 2.23701495e-01]
#  [ 9.60861613e-03]
#  [ 7.24094856e-01]
#  [ 2.63886642e-01]
#  [ 7.24094856e-01]
#  [ 2.75734824e-01]
#  [ 3.05199316e-01]
#  [ 2.78649481e-01]
#  [ 4.36628148e-01]
#  [ 4.36628148e-01]
#  [ 2.89696064e-01]
#  [ 1.20874899e-01]
#  [ 4.00927652e-01]
#  [ 4.95341003e-01]
#  [ 1.87427892e-01]
#  [ 7.42785830e-01]
#  [ 7.42785830e-01]
#  [ 6.17532228e-01]
#  [ 6.87988886e-02]
#  [ 6.87988886e-02]
#  [ 6.87988886e-02]
#  [ 6.87988886e-02]
#  [ 6.87988886e-02]
#  [ 6.87988886e-02]
#  [ 7.27992834e-02]
#  [ 7.42785830e-01]
#  [ 1.75727300e-01]
#  [ 1.75727300e-01]
#  [ 7.42785830e-01]
#  [ 7.42785830e-01]
#  [ 1.23737226e-01]
#  [ 5.19811457e-01]
#  [ 5.19811457e-01]
#  [ 5.19811457e-01]
#  [ 1.78960499e-01]
#  [ 2.12507462e-01]
#  [ 1.67147865e-01]
#  [ 1.75727300e-01]
#  [ 1.75727300e-01]
#  [ 4.16875190e-01]
#  [ 4.16875190e-01]
#  [ 4.36628148e-01]
#  [ 4.36628148e-01]
#  [ 2.75542165e-01]
#  [ 4.16875190e-01]
#  [ 3.30735914e-01]
#  [ 2.65310354e-01]
#  [ 1.61054109e-01]
#  [ 2.28889691e-01]
#  [ 1.38649985e-01]
#  [ 6.17532228e-01]
#  [ 3.41162574e-01]
#  [ 4.33305534e-01]
#  [ 0.00000000e+00]
#  [ 5.98896835e-02]
#  [ 1.30047639e-01]
#  [ 2.57637762e-01]
#  [ 1.71994903e-01]
#  [ 1.01806302e-01]
#  [ 7.99611056e-02]
#  [ 2.25020368e-01]
#  [ 3.08207362e-02]
#  [ 3.08207362e-02]
#  [ 3.08207362e-02]
#  [ 2.22693064e-01]
#  [ 2.23789500e-02]
#  [ 9.16460131e-02]
#  [ 4.52436153e-01]
#  [ 4.52436153e-01]
#  [ 1.41315866e-01]
#  [ 5.84113784e-02]
#  [ 1.58747029e-01]
#  [ 1.07708583e-01]
#  [ 2.53101542e-01]
#  [ 2.71497982e-03]
#  [ 2.33186421e-02]
#  [ 7.55396595e-03]
#  [ 3.41386193e-02]
#  [ 4.06353660e-02]
#  [ 7.55396595e-03]
#  [ 6.16744397e-02]
#  [ 1.70680631e-01]
#  [ 4.01534870e-01]
#  [ 1.65639512e-01]
#  [ 0.00000000e+00]
#  [ 1.51827964e-01]
#  [ 2.14351994e-01]
#  [ 4.81266788e-02]
#  [ 4.81266788e-02]
#  [ 3.71032272e-02]
#  [ 2.49280376e-01]
#  [ 1.91963559e-01]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 4.84628737e-02]
#  [ 9.89894944e-02]
#  [ 0.00000000e+00]
#  [ 3.30735914e-01]
#  [ 1.20874899e-01]
#  [ 1.68636734e-01]
#  [ 0.00000000e+00]
#  [ 2.05158070e-01]
#  [-2.00209463e-10]
#  [ 1.68825074e-01]
#  [ 5.51262805e-02]
#  [ 2.64048014e-02]
#  [ 1.71539755e-01]
#  [ 3.86126093e-02]
#  [ 4.81266788e-02]
#  [ 4.81266788e-02]
#  [ 1.66615244e-01]
#  [ 0.00000000e+00]
#  [ 2.22693064e-01]
#  [ 0.00000000e+00]
#  [ 7.24094856e-01]
#  [ 3.30735914e-01]
#  [ 1.68335109e-01]
#  [ 2.58459430e-01]
#  [ 2.33795366e-01]
#  [ 1.27301968e-01]
#  [ 2.14351994e-01]
#  [ 2.33186421e-02]
#  [ 7.96259499e-02]
#  [ 1.80269912e-01]
#  [ 5.05710743e-03]
#  [ 2.79080181e-01]
#  [ 2.79080181e-01]
#  [ 2.62389029e-01]
#  [ 1.24052017e-01]
#  [ 2.57637762e-01]
#  [ 1.40396269e-01]
#  [ 1.66477677e-01]
#  [ 1.66477677e-01]
#  [ 1.94936024e-01]
#  [ 2.66851270e-01]
#  [ 2.66851270e-01]
#  [ 5.16643057e-02]
#  [ 1.94936024e-01]
#  [ 1.24052017e-01]
#  [ 1.24052017e-01]
#  [ 1.52710654e-01]
#  [ 1.52710654e-01]
#  [ 1.49602968e-01]
#  [ 5.16643057e-02]
#  [ 1.97224839e-01]
#  [ 1.97224839e-01]
#  [ 2.79080181e-01]
#  [ 1.67596089e-01]
#  [ 5.16643057e-02]
#  [ 5.16643057e-02]
#  [ 2.51611466e-01]
#  [ 2.40572110e-01]
#  [ 5.16643057e-02]
#  [ 7.29080388e-02]
#  [ 6.41397063e-02]
#  [ 2.66851270e-01]
#  [ 1.24052017e-01]
#  [ 1.67596089e-01]
#  [ 1.24052017e-01]
#  [ 3.72220740e-02]
#  [ 5.16643057e-02]
#  [ 2.23364800e-01]
#  [ 1.24052017e-01]
#  [ 5.16643057e-02]
#  [ 1.15876915e-01]
#  [ 5.16643057e-02]
#  [ 7.24094856e-01]
#  [ 2.79080181e-01]
#  [ 8.63053489e-02]
#  [ 1.24052017e-01]
#  [ 2.62389029e-01]
#  [ 1.41254451e-01]
#  [ 1.41254451e-01]
#  [ 1.41254451e-01]
#  [ 1.41254451e-01]
#  [ 1.30550850e-01]
#  [ 1.50477545e-01]
#  [ 6.00632046e-02]
#  [ 1.76615424e-02]
#  [ 1.17950740e-02]]
# (522, 276)
# 0.0
# xtrain_nosvp (522, 289)
# [[9.04000000e-01 8.13000000e-01 4.00000000e+00 ... 7.20000000e+01
#   6.20000000e+01 4.90389038e-01]
#  [7.74000000e-01 8.38000000e-01 5.00000000e+00 ... 8.00000000e+01
#   7.80000000e+01 7.24094856e-01]
#  [6.64000000e-01 7.58000000e-01 2.00000000e+00 ... 8.70000000e+01
#   1.70000000e+01 4.95341003e-01]
#  ...
#  [5.95000000e-01 6.53000000e-01 7.00000000e+00 ... 6.40000000e+01
#   6.90000000e+01 6.00632046e-02]
#  [5.79000000e-01 8.01000000e-01 0.00000000e+00 ... 7.20000000e+01
#   6.10000000e+01 1.76615424e-02]
#  [5.86000000e-01 8.48000000e-01 1.10000000e+01 ... 5.60000000e+01
#   5.60000000e+01 1.17950740e-02]]
# (522, 14)

# %%
print(f"{X_train.nnz / np.prod(X_train.shape):.3f}")
print(f"About {X_train.nnz / np.prod(X_train.shape)*100:.3f}\% of the entries in the matrix are non zero")
# Out:
# 0.016
# About 1.637\% of the entries in the matrix are non zero

# %%
true_k = 10

model = KMeans(n_clusters=true_k, init='k-means++', max_iter=500, n_init=100)
model.fit(f_xtrain_nosvp)
#print(model.labels_)
#print(len(model.labels_))

for index, value in enumerate(model.labels_):
    print(string_field[index], value)
    if index == 10:
        break
print('Top terms per cluster')
order_centroids = model.cluster_centers_.argsort()[:,::-1]
terms = vectorizer.get_feature_names_out()
#print(terms)
for i in range(true_k):
    print(f"Cluster {i}: ", end="")
    for ind in order_centroids[i,:10]:
        print(f"{terms[ind]} ", end="")
    print()
# Out:
# dance urban hop hip virginia soul rhythm blues pop contemporary rap neo 5
# dance pop 5
# rhythm blues pop 0
# dance pop 9
# dance reggae pop fusion rap 0
# carolina dance south urban hop hip rhythm blues pop contemporary rap atl 9
# carolina dance south urban hop hip rhythm blues pop contemporary rap atl 9
# carolina dance south urban hop hip rhythm blues pop contemporary rap atl 9
# dance pop group girl 4
# dance urban rhythm blues pop contemporary group girl 5
# old atlanta south hop hip dirty school southern rap atl 9
# Top terms per cluster
# Cluster 0: america anthemfolk americana area aesthetic adult acoustic ambient album alternative
# Cluster 1: america anthemfolk area americana aesthetic acoustic adult ambient album melancholia
# Cluster 2: america anthemfolk americana area aesthetic adult acoustic ambient album alternative
# Cluster 3: america anthemfolk area americana aesthetic adult acoustic ambient alternative alt
# Cluster 4: america anthemfolk area americana aesthetic adult ambient acoustic alternative album
# Cluster 5: america anthemfolk area americana aesthetic adult acoustic ambient alternative drum
# Cluster 6: america anthemfolk area americana aesthetic adult acoustic ambient album southern
# Cluster 7: america anthemfolk americana aesthetic area adult ambient acoustic melancholia melbourne
# Cluster 8: america anthemfolk area americana aesthetic adult acoustic ambient album alternative
# Cluster 9: america anthemfolk americana area aesthetic adult acoustic ambient queen album

# %%
true_k = 10

model = KMeans(n_clusters=true_k, init='k-means++', max_iter=500, n_init=100)
model.fit(X_train)
#print(model.labels_)
#print(len(model.labels_))

for index, value in enumerate(model.labels_):
    print(string_field[index], value)
    if index == 10:
        break
print('Top terms per cluster')
order_centroids = model.cluster_centers_.argsort()[:,::-1]
terms = vectorizer.get_feature_names_out()
#print(terms)
for i in range(true_k):
    print(f"Cluster {i}: ", end="")
    for ind in order_centroids[i,:10]:
        print(f"{terms[ind]} ", end="")
    print()
# Out:
# dance urban hop hip virginia soul rhythm blues pop contemporary rap neo 2
# dance pop 5
# rhythm blues pop 7
# dance pop 5
# dance reggae pop fusion rap 5
# carolina dance south urban hop hip rhythm blues pop contemporary rap atl 2
# carolina dance south urban hop hip rhythm blues pop contemporary rap atl 2
# carolina dance south urban hop hip rhythm blues pop contemporary rap atl 2
# dance pop group girl 5
# dance urban rhythm blues pop contemporary group girl 7
# old atlanta south hop hip dirty school southern rap atl 2
# Top terms per cluster
# Cluster 0: wave permanent rock alternative metal funk new grunge synthpop romantic
# Cluster 1: modern rock stomp pop alternative indie holler chamber baroque welsh
# Cluster 2: hip hop rap miami dance pop atl urban contemporary rhythm
# Cluster 3: kpop group boy girl pop krap german gaze garage filter
# Cluster 4: classic album hard rock metal invasion british beatlesque progressive glam
# Cluster 5: dance pop rap postteen art funky neo uk australian mellow
# Cluster 6: country road contemporary outlaw classic nashville texas sound rock singersongwriter
# Cluster 7: rhythm blues korean krap kpop rap pop contemporary urban soul
# Cluster 8: indie pov garage rock australian pop electropop poptimism hypnagogic brisbane
# Cluster 9: pop punk scorecore rock shoegaze british neon hardcore canadian posthardcore

# %%
true_k = 10

model = KMeans(n_clusters=true_k, init='k-means++', max_iter=500, n_init=100)
model.fit(f_xtrain)
#print(model.labels_)
#print(len(model.labels_))

for index, value in enumerate(model.labels_):
    print(string_field[index], text_X_train[index], value)
    if index == 10:
        break
    
print('Top terms per cluster')
order_centroids = model.cluster_centers_.argsort()[:,::-1]
terms = vectorizer.get_feature_names_out()
#print(terms)
for i in range(true_k):
    print(f"Cluster {i}: ", end="")
    for ind in order_centroids[i,:10]:
        print(f"{terms[ind]} ", end="")
    print()
# Out:
# dance urban hop hip virginia soul rhythm blues pop contemporary rap neo [0.49038904] 3
# dance pop [0.72409486] 3
# rhythm blues pop [0.495341] 6
# dance pop [0.72409486] 5
# dance reggae pop fusion rap [0.40833619] 6
# carolina dance south urban hop hip rhythm blues pop contemporary rap atl [0.50498025] 5
# carolina dance south urban hop hip rhythm blues pop contemporary rap atl [0.50498025] 5
# carolina dance south urban hop hip rhythm blues pop contemporary rap atl [0.50498025] 5
# dance pop group girl [0.44806366] 1
# dance urban rhythm blues pop contemporary group girl [0.51926163] 3
# old atlanta south hop hip dirty school southern rap atl [0.13890203] 5
# Top terms per cluster
# Cluster 0: america anthemfolk americana area aesthetic adult acoustic ambient album alternative
# Cluster 1: america anthemfolk area americana aesthetic adult ambient acoustic art alternative
# Cluster 2: america anthemfolk area americana aesthetic adult acoustic ambient alternative alt
# Cluster 3: america anthemfolk area americana aesthetic adult acoustic ambient art alternative
# Cluster 4: america anthemfolk area americana aesthetic adult acoustic ambient album alt
# Cluster 5: america anthemfolk americana area aesthetic adult acoustic ambient art album
# Cluster 6: america anthemfolk americana area aesthetic adult acoustic ambient art album
# Cluster 7: america anthemfolk area americana aesthetic acoustic adult ambient album art
# Cluster 8: america anthemfolk area americana aesthetic adult acoustic ambient album alternative
# Cluster 9: america anthemfolk americana aesthetic area adult ambient acoustic art album

# %%
song_features_array

# %% [markdown]
# # Fuzzy Clustering

# %% [markdown]
# ## Fuzzy clustering algorithm (with no text features)

# %%
#check_df
#df_song_features

# %%
df = df_song_features
#df

# %%
# Specify INPUT songs list

input_songs_indices = [1, 212, 213, 214, 215, 216, 217, 218, 200, 300, 400, 500, 514]

input_songs_data = df.loc[input_songs_indices]
print('PLAYLIST OF INPUT SONGS ARE:')
print()
print(check_df['playlist_name'][input_songs_indices])
#print(check_df['track_track_name'][input_songs_indices])
# Out:
# PLAYLIST OF INPUT SONGS ARE:
#
# 1                Throwbacks
# 212                     mat
# 213                     mat
# 214                     mat
# 215                     mat
# 216                     mat
# 217                     mat
# 218                     mat
# 200                     mat
# 300                     90s
# 400    I Put A Spell On You
# 500                     BOP
# 514            old country
# Name: playlist_name, dtype: object

# %%
# Fuzzy Clustering algorithm (no text features)

import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
import skfuzzy as fuzz

# Step 1: Load the song data
song_data = df

# Step 2: Define the input songs
#input_songs = ['White Christmas', 'Let It Snow! Let It Snow! Let It Snow!', 'Jingle Bell Rock', 'Winter Wonderland']

# Step 4: Preprocess numerical features
numerical_features = ['danceability', 'energy', 'key', 'loudness',
       'speechiness', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo', 'song_popularity', 'artist_popularity', 'album_popularity'] #['artist_fraction', 'playlist_description_encoded']  # Replace with the actual numerical feature column names
all_songs_numerical = song_data[numerical_features]
input_songs_numerical = input_songs_data[numerical_features]

# Step 5: Preprocess categorical features
#categorical_features = ['track_track_name', 'playlist_name']  # Replace with the actual categorical feature column names
#all_songs_categorical = song_data[categorical_features]
#input_songs_categorical = input_songs_data[categorical_features]

# Step 6: Perform one-hot encoding on categorical features
encoder = OneHotEncoder(sparse_output=False)
#all_songs_categorical_encoded = encoder.fit_transform(all_songs_categorical)
#input_songs_categorical_encoded = encoder.transform(input_songs_categorical)

# Step 7: Combine numerical and categorical features
all_songs_combined = all_songs_numerical #np.concatenate((all_songs_numerical, all_songs_categorical_encoded), axis=1)
input_songs_combined = input_songs_numerical #np.concatenate((input_songs_numerical, input_songs_categorical_encoded), axis=1)

# Step 8: Scale the feature values
scaler = MinMaxScaler()
X_combined = scaler.fit_transform(all_songs_combined)
input_songs_combined_scaled = scaler.transform(input_songs_combined)

# Step 9: Train the fuzzy clustering model
num_clusters = 7
cntr, u, _, _, _, _, _ = fuzz.cluster.cmeans(X_combined.T, num_clusters, m=1.00001, error=0.000005, maxiter=50000)

# Step 10: Predict the degree of membership for all songs
all_songs_membership = fuzz.cluster.cmeans_predict(X_combined.T, cntr, 2, error=0.000005, maxiter=50000)[0]

# Step 11: Predict the degree of membership for the input songs
input_songs_membership = fuzz.cluster.cmeans_predict(input_songs_combined_scaled.T, cntr, 2, error=0.000005, maxiter=50000)[0]

# %%
print('membership matrix of input songs into different clusters:')
#input_songs_membership
# Out:
# membership matrix of input songs into different clusters:

# %%
print('membership matrix of all songs into different clusters:')
#all_songs_membership
# Out:
# membership matrix of all songs into different clusters:

# %%
# membership cluster ranking for all songs(clusters get distant from left to right)

all_songs_membership_array = []
for song_membership in all_songs_membership.T:
    all_sorted_indices = np.argsort(song_membership)[::-1]
    all_songs_membership_array.append(all_sorted_indices)

print('membership cluster ranking for all songs(clusters get distant from left to right):')
#all_songs_membership_array
# Out:
# membership cluster ranking for all songs(clusters get distant from left to right):

# %%
# cluster ranking for each input song
print('cluster ranking for each input tarck:')
print('')
i = 0
cluster_num_string_array = []
sorted_indices_array = []

for input_membership_array in input_songs_membership.T:
    sorted_indices = np.argsort(input_membership_array)[::-1]
    sorted_indices_array.append(sorted_indices)
    
    cluster_num_string = "Cluster ranks for Input Track {}:    ".format(i)
    cluster_num_string_array.append(cluster_num_string)
    
    i=i+1
    
test_encoding = tuple(zip(cluster_num_string_array , sorted_indices_array))

for cluster_rankings in test_encoding:
    cluster_label = cluster_rankings[0]
    cluster_array = cluster_rankings[1].tolist()
    print(cluster_label, cluster_array)
# Out:
# cluster ranking for each input tarck:
#
# Cluster ranks for Input Track 0:     [0, 5, 4, 6, 1, 2, 3]
# Cluster ranks for Input Track 1:     [3, 6, 2, 1, 4, 5, 0]
# Cluster ranks for Input Track 2:     [3, 4, 6, 5, 1, 2, 0]
# Cluster ranks for Input Track 3:     [6, 3, 5, 0, 1, 2, 4]
# Cluster ranks for Input Track 4:     [3, 1, 6, 5, 0, 2, 4]
# Cluster ranks for Input Track 5:     [3, 6, 5, 1, 4, 2, 0]
# Cluster ranks for Input Track 6:     [1, 6, 0, 3, 2, 4, 5]
# Cluster ranks for Input Track 7:     [6, 1, 0, 3, 4, 2, 5]
# Cluster ranks for Input Track 8:     [3, 4, 5, 6, 2, 1, 0]
# Cluster ranks for Input Track 9:     [5, 4, 0, 6, 2, 3, 1]
# Cluster ranks for Input Track 10:     [5, 4, 6, 0, 3, 1, 2]
# Cluster ranks for Input Track 11:     [0, 5, 4, 6, 2, 1, 3]
# Cluster ranks for Input Track 12:     [4, 5, 2, 3, 0, 6, 1]

# %%
# final cluster ranking by considering distance of all songs to all clusters

input_songs_membership_sum = np.sum(input_songs_membership.T, axis=0)
input_songs_membership_sum

input_songs_membership_sorted_indices = np.argsort(input_songs_membership_sum)[::-1]
print('Final cluster ranking by considering distance from each input track to each cluster center:')
print('')
print(input_songs_membership_sorted_indices)
# Out:
# Final cluster ranking by considering distance from each input track to each cluster center:
#
# [3 5 6 4 0 1 2]

# %%
# finding best matching track

refinement = 1

target_array = input_songs_membership_sorted_indices[0:refinement]

matching_index = None

# Iterating over the array list
for index, arr in enumerate(all_songs_membership_array):
    # Checking if the first two entries match

    if np.array_equal(arr[:refinement], target_array):
        matching_index = index
        #break  # Exit the loop after finding the first match

# Printing the matching index
    if matching_index is not None:
        #print("Matching index:", matching_index)
        #print("Matching Track:", check_df["track_track_name"][matching_index])
        print("Playlist of matching Track:", check_df['playlist_name'][matching_index])
        
        print('')
    #else:
        #print("No match found.")
    matching_index = None
if matching_index is None:
    print("No match found.")
# Out:
# Playlist of matching Track: Throwbacks
#
# Playlist of matching Track: korean
#
# Playlist of matching Track: korean
#
# Playlist of matching Track: korean
#
# Playlist of matching Track: korean
#
# Playlist of matching Track: korean
#
# Playlist of matching Track: korean
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: 90s
#
# Playlist of matching Track: Wedding
#
# Playlist of matching Track: Wedding
#
# Playlist of matching Track: Wedding
#
# Playlist of matching Track: Wedding
#
# Playlist of matching Track: I Put A Spell On You
#
# Playlist of matching Track: 2017
#
# Playlist of matching Track: 2017
#
# Playlist of matching Track: 2017
#
# Playlist of matching Track: 2017
#
# Playlist of matching Track: 2017
#
# Playlist of matching Track: 2017
#
# Playlist of matching Track: 2017
#
# Playlist of matching Track: 2017
#
# Playlist of matching Track: 2017
#
# Playlist of matching Track: 2017
#
# No match found.

# %% [markdown]
# ## Fuzzy clustering algorithm (with text features)

# %%
# DF Preparation (with text_data)

numerical_features = ['danceability', 'energy', 'key', 'loudness',
       'speechiness', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo', 'song_popularity', 'artist_popularity', 'album_popularity']

all_features = numerical_features + ['text_data']
df_with_text = pd.DataFrame(np.concatenate((df_song_features, text_X_train), axis=1), columns=all_features)

df = df_with_text

# %%
# Specify INPUT songs list

input_songs_indices = [1, 212, 213, 214, 215, 216, 217, 218, 200, 300, 400, 500, 514]

input_songs_data = df.loc[input_songs_indices]
print('PLAYLIST OF INPUT SONGS ARE:')
print()
print(check_df['playlist_name'][input_songs_indices])
#print(check_df['track_track_name'][input_songs_indices])
# Out:
# PLAYLIST OF INPUT SONGS ARE:
#
# 1                Throwbacks
# 212                     mat
# 213                     mat
# 214                     mat
# 215                     mat
# 216                     mat
# 217                     mat
# 218                     mat
# 200                     mat
# 300                     90s
# 400    I Put A Spell On You
# 500                     BOP
# 514            old country
# Name: playlist_name, dtype: object

# %%
# Fuzzy Clustering algorithm (with text features)

import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
import skfuzzy as fuzz

# Step 1: Load the song data
song_data = df

# Step 2: Define the input songs
#input_songs = ['White Christmas', 'Let It Snow! Let It Snow! Let It Snow!', 'Jingle Bell Rock', 'Winter Wonderland']

# Step 4: Preprocess numerical features
numerical_features = ['danceability', 'energy', 'key', 'loudness',
       'speechiness', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo', 'song_popularity', 'artist_popularity', 'album_popularity', 'text_data'] #['artist_fraction', 'playlist_description_encoded']  # Replace with the actual numerical feature column names

all_songs_numerical = song_data[numerical_features]
input_songs_numerical = input_songs_data[numerical_features]

# Step 5: Preprocess categorical features
#categorical_features = ['text_data']  # Replace with the actual categorical feature column names
#all_songs_categorical = song_data[categorical_features]
#input_songs_categorical = input_songs_data[categorical_features]

# Step 6: Perform one-hot encoding on categorical features
encoder = OneHotEncoder(sparse_output=False)
#all_songs_categorical_encoded = encoder.fit_transform(all_songs_categorical)
#input_songs_categorical_encoded = encoder.transform(input_songs_categorical)

# Step 7: Combine numerical and categorical features
all_songs_combined = all_songs_numerical #np.concatenate((all_songs_numerical, all_songs_categorical_encoded), axis=1)
input_songs_combined = input_songs_numerical #np.concatenate((input_songs_numerical, input_songs_categorical_encoded), axis=1)

# Step 8: Scale the feature values
scaler = MinMaxScaler()
X_combined = scaler.fit_transform(all_songs_combined)
input_songs_combined_scaled = scaler.transform(input_songs_combined)

# Step 9: Train the fuzzy clustering model
num_clusters = 7
cntr, u, _, _, _, _, _ = fuzz.cluster.cmeans(X_combined.T, num_clusters, m=1.00001, error=0.000005, maxiter=50000)

# Step 10: Predict the degree of membership for all songs
all_songs_membership = fuzz.cluster.cmeans_predict(X_combined.T, cntr, 2, error=0.000005, maxiter=50000)[0]

# Step 11: Predict the degree of membership for the input songs
input_songs_membership = fuzz.cluster.cmeans_predict(input_songs_combined_scaled.T, cntr, 2, error=0.000005, maxiter=50000)[0]

# %%
print('membership matrix of input songs into different clusters:')
#input_songs_membership
# Out:
# membership matrix of input songs into different clusters:

# %%
print('membership matrix of all songs into different clusters:')
#all_songs_membership
# Out:
# membership matrix of all songs into different clusters:

# %%
# membership cluster ranking for all songs(clusters get distant from left to right)

all_songs_membership_array = []
for song_membership in all_songs_membership.T:
    all_sorted_indices = np.argsort(song_membership)[::-1]
    all_songs_membership_array.append(all_sorted_indices)

print('membership cluster ranking for all songs(clusters get distant from left to right):')
#all_songs_membership_array
# Out:
# membership cluster ranking for all songs(clusters get distant from left to right):

# %%
# cluster ranking for each input song
print('cluster ranking for each input tarck:')
print('')
i = 0
cluster_num_string_array = []
sorted_indices_array = []

for input_membership_array in input_songs_membership.T:
    sorted_indices = np.argsort(input_membership_array)[::-1]
    sorted_indices_array.append(sorted_indices)
    
    cluster_num_string = "Cluster ranks for Input Track {}:    ".format(i)
    cluster_num_string_array.append(cluster_num_string)
    
    i=i+1
    
test_encoding = tuple(zip(cluster_num_string_array , sorted_indices_array))

for cluster_rankings in test_encoding:
    cluster_label = cluster_rankings[0]
    cluster_array = cluster_rankings[1].tolist()
    print(cluster_label, cluster_array)
# Out:
# cluster ranking for each input tarck:
#
# Cluster ranks for Input Track 0:     [5, 0, 2, 1, 4, 3, 6]
# Cluster ranks for Input Track 1:     [3, 1, 2, 4, 6, 0, 5]
# Cluster ranks for Input Track 2:     [3, 0, 6, 4, 2, 1, 5]
# Cluster ranks for Input Track 3:     [2, 3, 1, 4, 5, 0, 6]
# Cluster ranks for Input Track 4:     [3, 4, 2, 1, 0, 5, 6]
# Cluster ranks for Input Track 5:     [3, 2, 4, 0, 1, 6, 5]
# Cluster ranks for Input Track 6:     [4, 2, 1, 3, 5, 6, 0]
# Cluster ranks for Input Track 7:     [2, 4, 5, 3, 1, 0, 6]
# Cluster ranks for Input Track 8:     [3, 0, 2, 6, 1, 4, 5]
# Cluster ranks for Input Track 9:     [0, 5, 2, 1, 6, 3, 4]
# Cluster ranks for Input Track 10:     [0, 2, 5, 3, 1, 6, 4]
# Cluster ranks for Input Track 11:     [0, 5, 2, 1, 6, 4, 3]
# Cluster ranks for Input Track 12:     [6, 0, 1, 3, 2, 5, 4]

# %%
# final cluster ranking by considering distance of all songs to all clusters

input_songs_membership_sum = np.sum(input_songs_membership.T, axis=0)
input_songs_membership_sum

input_songs_membership_sorted_indices = np.argsort(input_songs_membership_sum)[::-1]
print('Final cluster ranking by considering distance from each input track to each cluster center:')
print('')
print(input_songs_membership_sorted_indices)
# Out:
# Final cluster ranking by considering distance from each input track to each cluster center:
#
# [3 0 2 4 5 1 6]

# %%
# finding the best matching track

refinement = 2

target_array = input_songs_membership_sorted_indices[0:refinement]

matching_index = None

# Iterating over the array list
for index, arr in enumerate(all_songs_membership_array):
    # Checking if the first two entries match

    if np.array_equal(arr[:refinement], target_array):
        matching_index = index
        #break  # Exit the loop after finding the first match

# Printing the matching index
    if matching_index is not None:
        #print("Matching index:", matching_index)
        #print("Matching Track:", check_df["track_track_name"][matching_index])
        print("Playlist of matching Track:", check_df['playlist_name'][matching_index])
        
        print('')
    #else:
        #print("No match found.")
    matching_index = None
if matching_index is None:
    print("No match found.")
# Out:
# Playlist of matching Track: Throwbacks
#
# Playlist of matching Track: korean
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: mat
#
# Playlist of matching Track: Wedding
#
# No match found.
